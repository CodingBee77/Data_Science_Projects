# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %% [markdown]
# # Request the website content and create bs object

# %%
r = requests.get("https://loczek.pl/")
soup = bs(r.content, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="pl-PL">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta class="foundation-mq"/>
#   <meta content="pwWy_Jxr32AJXBuB0EhiMKD_88xf0ilaDuLpjpCAYvU" name="google-site-verification"/>
#   <link href="https://loczek.pl/xmlrpc.php" rel="pingback"/>
#   <title>
#    Loczek.pl - sklep z naturalnymi kosmetykami do pielęgnacji włosów.
#   </title>
#   <link data-minify="1" href="https://loczek.pl/wp-content/cache/min/1/f4a2e9b11eedbdbe32511e3ec0e44938.css" media="all" rel="stylesheet"/>
#   <meta content="Sklep internetowy z kosmetykami i akcesoriami do włosów kręconych oraz zwolenników świadomej pielęgnacji. Zaawansowana wyszukiwarka umożliwia dobranie odpowiednich kosmetyków do Twojego typu włosów." name="description"/>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <link href="https://loczek.pl/" rel="canonical"/>
#   <meta content="pl_PL" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Loczek.pl - sklep z naturalnymi kosmetykami do pielęgnacji włosów." property="og:title"/>
#   <meta content="Sklep internetowy z kosmetykami i akcesoriami do włosów kręconych oraz zwolenników świadomej pielęgnacji. Zaawansowana wyszukiwarka umożliwia dobranie odpowiednich kosmetyków do Twojego typu włosów." property="og:description"/>
#   <meta content="https://loczek.pl/" property="og:url"/>
#   <meta content="Loczek.pl - sklep z kosmetykami do naturalnej pielęgnacji włosów" property="og:site_name"/>
#   <meta content="2020-09-17T11:35:11+00:00" property="article:modified_time"/>
#   <meta content="https://loczek.pl/wp-content/uploads/2020/03/obraz_loczek-pl-2.png" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="summary" name="twitter:card"/>
#   <link href="//maps.googleapis.com" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <style id="yith-wcwl-main-inline-css" type="text/css">
#    .yith-wcwl-share li a{color: #FFFFFF;}.yith-wcwl-share li a:hover{color: #FFFFFF;}.yith-wcwl-share a.facebook{background: #39599E; background-color: #39599E;}.yith-wcwl-share a.facebook:hover{background: #595A5A; background-color: #595A5A;}.yith-wcwl-share a.email{background: #FBB102; background-color: #FBB102;}.yith-wcwl-share a.email:hover{background: #595A5A; background-color: #595A5A;}.yith-wcwl-share a.whatsapp{background: #00A901; background-color: #00A901;}.yith-wcwl-share a.whatsapp:hover{background: #595A5A; background-color: #595A5A;}
#   </style>
#   <style id="woocommerce-inline-inline-css" type="text/css">
#    .woocommerce form .form-row .required { visibility: visible; }
#   </style>
#   <style id="yith-wcwtl-style-inline-css" type="text/css">
#    #yith-wcwtl-output .button.alt{background:#a46497;color:#ffffff;}
# 			#yith-wcwtl-output .button.alt:hover{background:#935386;color:#ffffff;}
# 			#yith-wcwtl-output .button.button-leave.alt{background:#a46497;color:#ffffff;}
# 			#yith-wcwtl-output .button.button-leave.alt:hover{background:#935386;color:#ffffff;}
# 			#yith-wcwtl-output p, #yith-wcwtl-output label{font-size:15px;color:#333333;}
#   </style>
#   <script id="favorites-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var favorites_data = {"ajaxurl":"https:\/\/loczek.pl\/wp-admin\/admin-ajax.php","nonce":"eb0dd96daa","favorite":"<i class=\"icon-favorite\"><\/i><span>Dodaj do ulubionych<\/span>","favorited":"<i class=\"icon-heart\"><\/i><span>Usu\u0144 z ulubionych<\/span>","includecount":"","indicate_loading":"","loading_text":"Loading","loading_image":"","loading_image_active":"","loading_image_preload":"","cache_enabled":"1","button_options":{"button_type":"custom","custom_colors":false,"box_shadow":false,"include_count":false,"default":{"background_default":false,"border_default":false,"text_default":false,"icon_default":false,"count_default":false},"active":{"background_active":false,"border_active":false,"text_active":false,"icon_active":false,"count_active":false}},"authentication_modal_content":"<p>Please login to add favorites.<\/p>\n<p><a href=\"#\" data-favorites-modal-close>Dismiss this notice<\/a><\/p>\n","authentication_redirect":"","dev_mode":"","logged_in":"","user_id":"0","authentication_redirect_url":"https:\/\/loczek.pl\/wp-login.php"};
# /* ]]> */
#   </script>
#   <link href="https://loczek.pl/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://loczek.pl/wp-json/wp/v2/pages/703" rel="alternate" type="application/json"/>
#   <meta content="Qedux 4.0.0.1" name="framework"/>
#   <style type="text/css">
#    .dgwt-wcas-ico-magnifier,.dgwt-wcas-ico-magnifier-handler{max-width:20px}.dgwt-wcas-search-wrapp{max-width:800px}
#   </style>
#   <noscript>
#    <style>
#     .woocommerce-product-gallery{ opacity: 1 !important; }
#    </style>
#   </noscript>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-138253092-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#                   function gtag(){dataLayer.push(arguments);}
#                   gtag("js", new Date());
#                   gtag("config", "UA-138253092-1",{"anonymize_ip":true, "cookie_domain":"auto"});
#   </script>
#   <link href="https://loczek.pl/wp-content/uploads/2019/04/favicon-1-64x64.png" rel="icon" sizes="32x32"/>
#   <link href="https://loczek.pl/wp-content/uploads/2019/04/favicon-1.png" rel="icon" sizes="192x192"/>
#   <link href="https://loczek.pl/wp-content/uploads/2019/04/favicon-1.png" rel="apple-touch-icon"/>
#   <meta content="https://loczek.pl/wp-content/uploads/2019/04/favicon-1.png" name="msapplication-TileImage"/>
#  </head>
#  <body class="home page-template page-template-front-page page-template-front-page-php page page-id-703 wp-custom-logo theme-loczek woocommerce-no-js" data-rsssl="1">
#   <div class="promo-bar text-center">
#    WYSYŁKA 24h • 100% EKO pakowanie • DARMOWA DOSTAWA od 199 zł
#   </div>
#   <div class="off-canvas-wrapper">
#    <div class="off-canvas position-right" data-off-canvas="" id="off-canvas">
#     <ul class="vertical menu" data-accordion-menu="" id="menu-main-menu">
#      <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-960" id="menu-item-960">
#       <a href="https://loczek.pl/marki/">
#        Marki
#       </a>
#      </li>
#      <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-1080" id="menu-item-1080">
#       <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-niskoporowate,wlosy-srednioporowate,wlosy-wysokoporowate">
#        Porowatość włosów
#       </a>
#       <ul class="vertical menu">
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-25606" id="menu-item-25606">
#         <a href="https://loczek.pl/test-na-porowatosc/">
#          TEST NA POROWATOŚĆ
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1021" id="menu-item-1021">
#         <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-niskoporowate">
#          Niskoporowate
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1020" id="menu-item-1020">
#         <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-srednioporowate">
#          Średnioporowate
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1019" id="menu-item-1019">
#         <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-wysokoporowate">
#          Wysokoporowate
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-1033" id="menu-item-1033">
#       <a href="https://loczek.pl/sklep/?filter_peh=emolienowe,humektantowe,proteinowe">
#        Według PEH
#       </a>
#       <ul class="vertical menu">
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1034" id="menu-item-1034">
#         <a href="https://loczek.pl/sklep/?filter_peh=emolientowe">
#          Emolientowe
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1036" id="menu-item-1036">
#         <a href="https://loczek.pl/sklep/?filter_peh=humektantowe">
#          Humektantowe
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1035" id="menu-item-1035">
#         <a href="https://loczek.pl/sklep/?filter_cg=produkty-cg&amp;filter_peh=proteinowe">
#          Proteinowe
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1032" id="menu-item-1032">
#       <a href="https://loczek.pl/sklep/?filter_cg=produkty-cg">
#        Produkty CG
#       </a>
#      </li>
#      <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2598" id="menu-item-2598">
#       <a href="https://loczek.pl/lista-ulubionych/">
#        Lista ulubionych
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="off-canvas-content" data-off-canvas-content="">
#     <header class="header" data-sticky-container="" id="banner" role="banner">
#      <div class="header__top">
#       <div class="row align-justify">
#        <div class="header__top__left">
#         <div class="header__lang">
#         </div>
#         <div class="header__search">
#         </div>
#        </div>
#        <div class="header__top__right">
#         <a class="header__top__profile" href="https://loczek.pl/moje-konto/">
#          Moje konto
#          <i class="icon-user">
#          </i>
#         </a>
#         <div class="header__cart">
#          <a class="header__cart__icon" href="https://loczek.pl/koszyk/">
#           <i class="icon-basket">
#           </i>
#           Koszyk
#           <span class="cart-number">
#            0
#           </span>
#          </a>
#          <div class="header__mobile-btn hide-for-large">
#           <ul class="menu">
#            <li>
#             <button class="menu-icon" data-toggle="off-canvas" type="button">
#             </button>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header__top2">
#       <div class="row align-center">
#        <div class="header__top__middle">
#         <div class="header__logo">
#          <a href="https://loczek.pl/">
#           <img alt="" class="logo" src="https://loczek.pl/wp-content/uploads/2020/04/ziolowaloczkowa_fit.svg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header__middle row align-center align-middle">
#       <div class="header__menu">
#        <ul class="vertical medium-horizontal menu" data-responsive-menu="accordion medium-dropdown" id="menu-top-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3208" id="menu-item-3208">
#          <a href="https://loczek.pl/sklep/">
#           Produkty
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-taxonomy menu-item-object-product_cat menu-item-35122" id="menu-item-35122">
#          <a href="https://loczek.pl/kategoria-produktu/zielarnia-loczka/">
#           Zielarnia
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-taxonomy menu-item-object-product_tag menu-item-1037" id="menu-item-1037">
#          <a href="https://loczek.pl/tag-produktu/wyprzedaze/">
#           Promocje
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1038" id="menu-item-1038">
#          <a href="https://loczek.pl/artykuly/">
#           Blog
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1039" id="menu-item-1039">
#          <a href="https://loczek.pl/spytaj-eksperta/">
#           Spytaj eksperta
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="header__bottom top-bar show-for-medium" id="top-bar-menu">
#       <div class="row expanded align-center">
#        <div class="header__nav">
#         <ul class="vertical medium-horizontal menu" data-responsive-menu="accordion medium-dropdown" id="menu-main-menu-1">
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-960">
#           <a href="https://loczek.pl/marki/">
#            Marki
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-1080">
#           <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-niskoporowate,wlosy-srednioporowate,wlosy-wysokoporowate">
#            Porowatość włosów
#           </a>
#           <ul class="menu">
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-25606">
#             <a href="https://loczek.pl/test-na-porowatosc/">
#              TEST NA POROWATOŚĆ
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1021">
#             <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-niskoporowate">
#              Niskoporowate
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1020">
#             <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-srednioporowate">
#              Średnioporowate
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1019">
#             <a href="https://loczek.pl/sklep/?filter_porowatosc-wlosow=wlosy-wysokoporowate">
#              Wysokoporowate
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-1033">
#           <a href="https://loczek.pl/sklep/?filter_peh=emolienowe,humektantowe,proteinowe">
#            Według PEH
#           </a>
#           <ul class="menu">
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1034">
#             <a href="https://loczek.pl/sklep/?filter_peh=emolientowe">
#              Emolientowe
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1036">
#             <a href="https://loczek.pl/sklep/?filter_peh=humektantowe">
#              Humektantowe
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1035">
#             <a href="https://loczek.pl/sklep/?filter_cg=produkty-cg&amp;filter_peh=proteinowe">
#              Proteinowe
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1032">
#           <a href="https://loczek.pl/sklep/?filter_cg=produkty-cg">
#            Produkty CG
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2598">
#           <a href="https://loczek.pl/lista-ulubionych/">
#            Lista ulubionych
#           </a>
#          </li>
#         </ul>
#         <div class="dgwt-wcas-search-wrapp dgwt-wcas-has-submit woocommerce js-dgwt-wcas-layout-classic dgwt-wcas-layout-classic">
#          <form action="https://loczek.pl/" class="dgwt-wcas-search-form" method="get" role="search">
#           <div class="dgwt-wcas-sf-wrapp">
#            <label class="screen-reader-text" for="dgwt-wcas-search-input-15c1">
#             Wyszukiwarka produktów
#            </label>
#            <input autocomplete="off" class="dgwt-wcas-search-input" id="dgwt-wcas-search-input-15c1" name="s" placeholder="Szukaj produktów" type="search" value=""/>
#            <div class="dgwt-wcas-preloader">
#            </div>
#            <button class="dgwt-wcas-search-submit" name="dgwt-wcas-search-submit" type="submit">
#             Szukaj
#            </button>
#            <input name="post_type" type="hidden" value="product"/>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="hide-for-large search-small">
#       <div class="dgwt-wcas-search-wrapp dgwt-wcas-has-submit woocommerce js-dgwt-wcas-layout-classic dgwt-wcas-layout-classic">
#        <form action="https://loczek.pl/" class="dgwt-wcas-search-form" method="get" role="search">
#         <div class="dgwt-wcas-sf-wrapp">
#          <label class="screen-reader-text" for="dgwt-wcas-search-input-2e0f">
#           Wyszukiwarka produktów
#          </label>
#          <input autocomplete="off" class="dgwt-wcas-search-input" id="dgwt-wcas-search-input-2e0f" name="s" placeholder="Szukaj produktów" type="search" value=""/>
#          <div class="dgwt-wcas-preloader">
#          </div>
#          <button class="dgwt-wcas-search-submit" name="dgwt-wcas-search-submit" type="submit">
#           Szukaj
#          </button>
#          <input name="post_type" type="hidden" value="product"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </header>
#     <div class="home-slider__wrap row">
#      <div class="columns small-12">
#       <div class="home-slider">
#        <div class="home-slider__item">
#         <div class="home-slider__item__content">
#          <div class="home-slider__item__text">
#           <img alt="" src="https://loczek.pl/wp-content/uploads/2020/09/loczek_baner-www_hennowanie-02-1920x915.jpg"/>
#           <div class="home-slider__item__title1">
#            Hennowanie
#           </div>
#           <a class="home-slider__item__link" href="https://loczek.pl/ziolowa-pielegnacja-ci-sluzy/">
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="home-slider__item">
#         <div class="home-slider__item__content">
#          <div class="home-slider__item__text">
#           <img alt="" src="https://loczek.pl/wp-content/uploads/2020/08/loczek_bane-www_back-to-school-01-1920x915.png"/>
#           <div class="home-slider__item__title1">
#            Back To School
#           </div>
#           <a class="home-slider__item__link" href="https://loczek.pl/back-to-school/">
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="home-slider__item">
#         <div class="home-slider__item__content">
#          <div class="home-slider__item__text">
#           <img alt="" src="https://loczek.pl/wp-content/uploads/2020/07/banery-loczek.png"/>
#           <div class="home-slider__item__title1">
#            Mawawo
#           </div>
#           <a class="home-slider__item__link" href="https://loczek.pl/mawawo-natural-cosmetics/">
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="home-slider__item">
#         <div class="home-slider__item__content">
#          <div class="home-slider__item__text">
#           <img alt="" src="https://loczek.pl/wp-content/uploads/2020/08/porowatosc-2.png"/>
#           <div class="home-slider__item__title1">
#            Test na porowatość
#           </div>
#           <a class="home-slider__item__link" href="https://loczek.pl/praktyczny-test-na-porowatosc/">
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="columns small-10 small-offset-1 text-center spacer--bottom">
#        <p>
#         <strong>
#          Loczek.pl
#         </strong>
#         <br/>
#         Drogeria internetowa z kosmetykami i akcesoriami do włosów prostych, kręconych i falowanych oraz dla zwolenników świadomej pielęgnacji. Zaawansowana wyszukiwarka umożliwia dobranie odpowiednich kosmetyków do Twojego typu włosów. Szukaj ich według zapotrzebowania PEH, swojej porowatości lub ulubionego, sprawdzonego składnika. Do realizacji zamówienia przystępujemy zaraz po złożeniu zamówienia, do 24h. Zachęcamy do recenzowania zakupionych przedmiotów. Za zakupy i recenzje na stronie otrzymujesz punkty wymienne na zniżki.
#         <strong>
#          Twórz z nami Loczka!
#         </strong>
#        </p>
#       </div>
#      </div>
#     </div>
#     <section class="home-products row" id="nowosci">
#      <div class="columns">
#       <div class="home-products__title separator">
#        <span>
#         Nowości
#        </span>
#       </div>
#       <ul class="products row">
#        <li class="product columns small-12 medium-6 large-4 type-product post-5915 status-publish first instock product_cat-akcesoria product_tag-nowosci has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/lussoni-fryzjerska-wyciskarka-resztek-kosmetykow/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="new">
#              Nowość
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini-640x747.png" srcset="https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini.png 640w, https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini-129x150.png 129w, https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini-257x300.png 257w, https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini-300x350.png 300w, https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini-600x700.png 600w, https://loczek.pl/wp-content/uploads/2019/11/wyciskarka-mini-64x75.png 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            LUSSONI – Fryzjerska wyciskarka resztek kosmetyków
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               26,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “LUSSONI - Fryzjerska wyciskarka resztek kosmetyków” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="5915" data-product_sku="5903018917184" data-quantity="1" href="?add-to-cart=5915" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-6169 status-publish instock product_cat-akcesoria product_cat-czepki product_tag-bestsellery product_tag-nowosci product_tag-spanie product_tag-do-spania product_tag-na-sen has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/loczek-satynowy-czepek-do-spania-zabezpieczajacy-wlosy-krecone/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="new">
#              Nowość
#             </span>
#             <span class="bestseller">
#              Bestseller
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="615" loading="lazy" sizes="(max-width: 527px) 100vw, 527px" src="https://loczek.pl/wp-content/uploads/2019/11/formatka-1-5-xcf.png" srcset="https://loczek.pl/wp-content/uploads/2019/11/formatka-1-5-xcf.png 527w, https://loczek.pl/wp-content/uploads/2019/11/formatka-1-5-xcf-257x300.png 257w, https://loczek.pl/wp-content/uploads/2019/11/formatka-1-5-xcf-129x150.png 129w, https://loczek.pl/wp-content/uploads/2019/11/formatka-1-5-xcf-300x350.png 300w, https://loczek.pl/wp-content/uploads/2019/11/formatka-1-5-xcf-64x75.png 64w" width="527"/>
#           </div>
#           <div class="product__title">
#            LOCZEK – SATYNOWY CZEPEK DO SPANIA ZABEZPIECZAJĄCY WŁOSY KRĘCONE
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               19,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “LOCZEK - SATYNOWY CZEPEK DO SPANIA ZABEZPIECZAJĄCY WŁOSY KRĘCONE” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="6169" data-product_sku="5903707542154" data-quantity="1" href="?add-to-cart=6169" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-40912 status-publish last instock product_cat-naturalne-farbowanie product_cat-zielarnia-loczka product_cat-henna-naturalne-farbowanie product_tag-nowosci product_tag-srednioporowate product_tag-niskoporowate product_tag-henna product_tag-ziola product_tag-rudy product_tag-wysokoporowe product_tag-intensywny-rudy product_tag-cieple-tony product_tag-ziola-kondycjonujace product_tag-ziola-barwiace product_tag-miksohenna has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/miksohenna-henna-mocna-naturalna-henna-nadajaca-rudej-barwy/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="new">
#              Nowość
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl.png" srcset="https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl.png 640w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl-257x300.png 257w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl-129x150.png 129w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl-300x350.png 300w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl-600x700.png 600w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_loczek_pl-64x75.png 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            MIKSOHENNA HENNA -mocna, naturalna henna nadająca rudej barwy
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               34,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “MIKSOHENNA HENNA -mocna, naturalna henna nadająca rudej barwy” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="40912" data-product_sku="MIK002" data-quantity="1" href="?add-to-cart=40912" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-40957 status-publish first instock product_cat-naturalne-farbowanie product_cat-zielarnia-loczka product_cat-indygo product_tag-nowosci product_tag-wysokoporowate product_tag-srednioporowate product_tag-niskoporowate product_tag-naturalne-farbowanie product_tag-indygo product_tag-braz product_tag-naturalne-farbowanie-czarny product_tag-gleboki-braz product_tag-miksohenna product_tag-czarne-wlosy has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/miksohenna-indygo-naturalne-indygo-nadajace-czarny-kolor/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="new">
#              Nowość
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl.png" srcset="https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl.png 640w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl-257x300.png 257w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl-129x150.png 129w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl-300x350.png 300w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl-600x700.png 600w, https://loczek.pl/wp-content/uploads/2020/08/miksohenna_indygo_loczek_pl-64x75.png 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            MIKSOHENNA INDYGO – naturalne indygo nadające czarny kolor
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               34,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “MIKSOHENNA INDYGO - naturalne indygo nadające czarny kolor” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="40957" data-product_sku="MIK001" data-quantity="1" href="?add-to-cart=40957" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-51404 status-publish instock product_cat-bez-kategorii product_cat-spinki product_cat-ozdoby-do-wlosow product_tag-nowosci has-post-thumbnail sale sold-individually taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/loczek-zestaw-spinek-z-perelkami-2szt/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="onsale">
#              -23%
#             </span>
#             <span class="new">
#              Nowość
#             </span>
#            </div>
#            <img alt="Spinki z perełkami" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf.png" srcset="https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf.png 640w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-257x300.png 257w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-129x150.png 129w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-300x350.png 300w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-600x700.png 600w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-64x75.png 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            LOCZEK ZESTAW SPINEK Z PEREŁKAMI 2szt
#           </div>
#           <div class="product__prices">
#            <span class="current">
#             <span class="woocommerce-Price-amount amount">
#              9,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#            <span class="old">
#             <span class="woocommerce-Price-amount amount">
#              12,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#           </div>
#          </a>
#          <a aria-label="Dodaj “LOCZEK ZESTAW SPINEK Z PEREŁKAMI 2szt” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="51404" data-product_sku="5903707542123" data-quantity="1" href="?add-to-cart=51404" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-51407 status-publish last instock product_cat-bez-kategorii product_cat-spinki product_cat-ozdoby-do-wlosow product_tag-nowosci product_tag-specj has-post-thumbnail sale sold-individually taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/loczek-zestaw-spinek-z-perelkami-2szt-3/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="onsale">
#              -23%
#             </span>
#             <span class="new">
#              Nowość
#             </span>
#            </div>
#            <img alt="Spinki z perełkami" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2.png" srcset="https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2.png 640w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2-257x300.png 257w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2-129x150.png 129w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2-300x350.png 300w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2-600x700.png 600w, https://loczek.pl/wp-content/uploads/2020/09/formatka-1-8-xcf-2-64x75.png 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            LOCZEK ZESTAW SPINEK Z PEREŁKAMI 2szt
#           </div>
#           <div class="product__prices">
#            <span class="current">
#             <span class="woocommerce-Price-amount amount">
#              9,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#            <span class="old">
#             <span class="woocommerce-Price-amount amount">
#              12,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#           </div>
#          </a>
#          <a aria-label="Dodaj “LOCZEK ZESTAW SPINEK Z PEREŁKAMI 2szt” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="51407" data-product_sku="5903707542147" data-quantity="1" href="?add-to-cart=51407" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#       </ul>
#       <div class="home-products__footer text-center spacer--bottom">
#        <a class="home-products__link button--outline" href="https://loczek.pl/tag-produktu/nowosci/">
#         Zobacz wszystkie nowości
#        </a>
#       </div>
#      </div>
#     </section>
#     <section class="home-products row" id="bestsellery">
#      <div class="columns">
#       <div class="home-products__title separator">
#        <span>
#         Bestsellery
#        </span>
#       </div>
#       <ul class="products row">
#        <li class="product columns small-12 medium-6 large-4 type-product post-967 status-publish first instock product_cat-produkty-do-stylizacji product_cat-reanimacja product_cat-kremy product_tag-bestsellery has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/boots-essentials-curl-creme-krem-zel-do-lokow-cg-kopia/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="bestseller">
#              Bestseller
#             </span>
#             <span class="product_peh">
#              E
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2019/03/mini_boots-640x747.jpg" srcset="https://loczek.pl/wp-content/uploads/2019/03/mini_boots.jpg 640w, https://loczek.pl/wp-content/uploads/2019/03/mini_boots-129x150.jpg 129w, https://loczek.pl/wp-content/uploads/2019/03/mini_boots-257x300.jpg 257w, https://loczek.pl/wp-content/uploads/2019/03/mini_boots-300x350.jpg 300w, https://loczek.pl/wp-content/uploads/2019/03/mini_boots-600x700.jpg 600w, https://loczek.pl/wp-content/uploads/2019/03/mini_boots-64x75.jpg 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            BOOTS ESSENTIALS CURL CREME – krem do stylizacji
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               44,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “BOOTS ESSENTIALS CURL CREME - krem do stylizacji” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="967" data-product_sku="5045092467985" data-quantity="1" href="?add-to-cart=967" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-1004 status-publish instock product_cat-reanimacja product_cat-odzywki-b-s product_tag-bestsellery product_tag-cantu-aktywator product_tag-aktywator-skretu product_tag-swieta product_tag-back-to-school has-post-thumbnail sale taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/cantu-curl-activator-cream-aktywator-skretu/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="onsale">
#              -10%
#             </span>
#             <span class="bestseller">
#              Bestseller
#             </span>
#             <span class="product_cg">
#              CG
#             </span>
#             <span class="product_peh">
#              H
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="572" loading="lazy" sizes="(max-width: 374px) 100vw, 374px" src="https://loczek.pl/wp-content/uploads/2019/03/formatka-1-2-xcf.png" srcset="https://loczek.pl/wp-content/uploads/2019/03/formatka-1-2-xcf.png 374w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-2-xcf-196x300.png 196w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-2-xcf-98x150.png 98w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-2-xcf-300x459.png 300w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-2-xcf-64x98.png 64w" width="374"/>
#           </div>
#           <div class="product__title">
#            CANTU CURL ACTIVATOR CREAM – Aktywator skrętu
#           </div>
#           <div class="product__prices">
#            <span class="current">
#             <span class="woocommerce-Price-amount amount">
#              42,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#            <span class="old">
#             <span class="woocommerce-Price-amount amount">
#              47,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#           </div>
#          </a>
#          <a aria-label="Dodaj “CANTU CURL ACTIVATOR CREAM - Aktywator skrętu” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="1004" data-product_sku="817513010002" data-quantity="1" href="?add-to-cart=1004" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-1006 status-publish last instock product_cat-odzywki-i-maski product_tag-bestsellery product_tag-swieta has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/cantu-hydrating-nawilzajaca-odzywka-do-lokow/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="bestseller">
#              Bestseller
#             </span>
#             <span class="product_peh">
#              E
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="747" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1.png" srcset="https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1.png 640w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1-257x300.png 257w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1-129x150.png 129w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1-300x350.png 300w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1-600x700.png 600w, https://loczek.pl/wp-content/uploads/2019/03/formatka-1-3-xcf-1-64x75.png 64w" width="640"/>
#           </div>
#           <div class="product__title">
#            CANTU Hydrating Emolientowa odżywka do włosów o każdej porowatości
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               34,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “CANTU Hydrating Emolientowa odżywka do włosów o każdej porowatości” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="1006" data-product_sku="817513015328" data-quantity="1" href="?add-to-cart=1006" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-2562 status-publish first instock product_cat-akcesoria product_cat-grzebienie-i-szczotki product_tag-bestsellery product_tag-blackfriday product_tag-denman-3d product_tag-3d product_tag-back-to-school has-post-thumbnail sale taxable shipping-taxable purchasable product-type-variable">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/denman-d3-szczotka-do-stylizacji-wlosow-lokow-i-fal/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="onsale">
#              -9%
#             </span>
#             <span class="bestseller">
#              Bestseller
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="600" loading="lazy" sizes="(max-width: 560px) 100vw, 560px" src="https://loczek.pl/wp-content/uploads/2019/08/kha-098_0-1.png" srcset="https://loczek.pl/wp-content/uploads/2019/08/kha-098_0-1.png 560w, https://loczek.pl/wp-content/uploads/2019/08/kha-098_0-1-280x300.png 280w, https://loczek.pl/wp-content/uploads/2019/08/kha-098_0-1-140x150.png 140w, https://loczek.pl/wp-content/uploads/2019/08/kha-098_0-1-300x321.png 300w, https://loczek.pl/wp-content/uploads/2019/08/kha-098_0-1-64x69.png 64w" width="560"/>
#           </div>
#           <div class="product__title">
#            DENMAN D3 – szczotka do stylizacji włosów kręconych, loków, fal
#           </div>
#           <div class="product__prices">
#            <span class="current">
#             <span class="woocommerce-Price-amount amount">
#              49,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#            <span class="old">
#             <span class="woocommerce-Price-amount amount">
#              54,99
#              <span class="woocommerce-Price-currencySymbol">
#               zł
#              </span>
#             </span>
#            </span>
#           </div>
#          </a>
#          <a aria-label="Wybierz opcje dla “DENMAN D3 - szczotka do stylizacji włosów kręconych, loków, fal”" class="button product_type_variable add_to_cart_button" data-product_id="2562" data-product_sku="" data-quantity="1" href="https://loczek.pl/produkt/denman-d3-szczotka-do-stylizacji-wlosow-lokow-i-fal/" rel="nofollow">
#           Wybierz opcje
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-3838 status-publish instock product_cat-produkty-do-stylizacji product_cat-zele product_tag-bestsellery product_tag-cantu-zel has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
#          <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://loczek.pl/produkt/canty-stay-glue-extreme-hold-styling-gel-mocny-zel-do-stylizacji-wlosow-kreconych/">
#           <div class="product__thumb">
#            <div class="product__ribbons">
#             <span class="bestseller">
#              Bestseller
#             </span>
#             <span class="product_cg">
#              CG
#             </span>
#             <span class="product_peh">
#              H
#             </span>
#            </div>
#            <img alt="" class="attachment-foundation-small size-foundation-small" height="500" loading="lazy" sizes="(max-width: 396px) 100vw, 396px" src="https://loczek.pl/wp-content/uploads/2019/09/stay-glue-1-2.png" srcset="https://loczek.pl/wp-content/uploads/2019/09/stay-glue-1-2.png 396w, https://loczek.pl/wp-content/uploads/2019/09/stay-glue-1-2-238x300.png 238w, https://loczek.pl/wp-content/uploads/2019/09/stay-glue-1-2-119x150.png 119w, https://loczek.pl/wp-content/uploads/2019/09/stay-glue-1-2-300x379.png 300w, https://loczek.pl/wp-content/uploads/2019/09/stay-glue-1-2-64x81.png 64w" width="396"/>
#           </div>
#           <div class="product__title">
#            CANTU STAY GLUE MEGA HOLD STYLING GEL – mocny żel do stylizacji włosów kręconych
#           </div>
#           <div class="product__prices">
#            <div class="product__prices">
#             <span class="current">
#              <span class="woocommerce-Price-amount amount">
#               39,99
#               <span class="woocommerce-Price-currencySymbol">
#                zł
#               </span>
#              </span>
#             </span>
#            </div>
#           </div>
#          </a>
#          <a aria-label="Dodaj “CANTU STAY GLUE MEGA HOLD STYLING GEL - mocny żel do stylizacji włosów kręconych” do koszyka" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="3838" data-product_sku="817513016318" data-quantity="1" href="?add-to-cart=3838" rel="nofollow">
#           Dodaj do koszyka
#          </a>
#         </div>
#        </li>
#        <li class="product columns small-12 medium-6 large-4 type-product post-4226 status-publish last instock product_cat-myjadla product_cat-odzywki-i-maski product_tag-bestsellery product_tag-myjadlo product_tag-cg has-post-thumbnail taxable shipping-taxable purchasable product-type-simple">
#         <div class="inner">
# ...
# /* ]]> */
#   </script>
#   <script id="google-maps-api-js" src="//maps.googleapis.com/maps/api/js?key=AIzaSyDOhNUqCw6feVh_ueqBijH8BenN6TInFgU" type="text/javascript">
#   </script>
#   <script async="" defer="" id="google-invisible-recaptcha-js" src="https://www.google.com/recaptcha/api.js?onload=renderInvisibleReCaptcha&amp;render=explicit" type="text/javascript">
#   </script>
#   <script id="google-recaptcha-js" src="https://www.google.com/recaptcha/api.js?render=6LcFkaYUAAAAAKEr_hGqGWNTOF16rzd8hgVeP1CD&amp;ver=3.0" type="text/javascript">
#   </script>
#   <script id="wp-util-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var _wpUtilSettings = {"ajax":{"url":"\/wp-admin\/admin-ajax.php"}};
# /* ]]> */
#   </script>
#   <script type="text/javascript">
#    jQuery(function($) {
# tvc_lc="PLN";
#
# homepage_json_ATC_link={"?add-to-cart=5915":{"ATC-link":"https:\/\/loczek.pl\/produkt\/lussoni-fryzjerska-wyciskarka-resztek-kosmetykow\/"},"?add-to-cart=6169":{"ATC-link":"https:\/\/loczek.pl\/produkt\/loczek-satynowy-czepek-do-spania-zabezpieczajacy-wlosy-krecone\/"},"?add-to-cart=40912":{"ATC-link":"https:\/\/loczek.pl\/produkt\/miksohenna-henna-mocna-naturalna-henna-nadajaca-rudej-barwy\/"},"?add-to-cart=40957":{"ATC-link":"https:\/\/loczek.pl\/produkt\/miksohenna-indygo-naturalne-indygo-nadajace-czarny-kolor\/"},"?add-to-cart=51404":{"ATC-link":"https:\/\/loczek.pl\/produkt\/loczek-zestaw-spinek-z-perelkami-2szt\/"},"?add-to-cart=51407":{"ATC-link":"https:\/\/loczek.pl\/produkt\/loczek-zestaw-spinek-z-perelkami-2szt-3\/"},"?add-to-cart=967":{"ATC-link":"https:\/\/loczek.pl\/produkt\/boots-essentials-curl-creme-krem-zel-do-lokow-cg-kopia\/"},"?add-to-cart=1004":{"ATC-link":"https:\/\/loczek.pl\/produkt\/cantu-curl-activator-cream-aktywator-skretu\/"},"?add-to-cart=1006":{"ATC-link":"https:\/\/loczek.pl\/produkt\/cantu-hydrating-nawilzajaca-odzywka-do-lokow\/"},"https:\/\/loczek.pl\/produkt\/denman-d3-szczotka-do-stylizacji-wlosow-lokow-i-fal\/":{"ATC-link":"https:\/\/loczek.pl\/produkt\/denman-d3-szczotka-do-stylizacji-wlosow-lokow-i-fal\/"},"?add-to-cart=3838":{"ATC-link":"https:\/\/loczek.pl\/produkt\/canty-stay-glue-extreme-hold-styling-gel-mocny-zel-do-stylizacji-wlosow-kreconych\/"},"?add-to-cart=4226":{"ATC-link":"https:\/\/loczek.pl\/produkt\/complete-conditioning-co-wash\/"},"?add-to-cart=13157":{"ATC-link":"https:\/\/loczek.pl\/produkt\/karelia-organica-maska-rokitnikowa-peh-objetosc-i-blask-proteiny-roslinne-i-ekstrakty-owocowe\/"},"?add-to-cart=15716":{"ATC-link":"https:\/\/loczek.pl\/produkt\/eco-laboratorie-delikatny-szampon-dla-dzieci-1-bez-lez-biala-herbata-i-kwiat-lipy\/"},"?add-to-cart=20292":{"ATC-link":"https:\/\/loczek.pl\/produkt\/etja-nierafinowany-zimnotloczony-olej-z-pestek-granatu-do-wlosow-wysokoporowatych-i-srednioporowatych\/"},"?add-to-cart=24260":{"ATC-link":"https:\/\/loczek.pl\/produkt\/eco-laboratorie-man-szampon-i-zel-pod-prysznic-dla-mezczyzn-2in1-cyprys-i-zielona-herbata\/"},"?add-to-cart=39067":{"ATC-link":"https:\/\/loczek.pl\/produkt\/dary-natury-seria-domowy-zielnik-ziolowy-detox-wielofunkcyjna-mieszanka-ziol-pielegnujacych-w-ozdobnym-opakowaniu\/"},"?add-to-cart=41052":{"ATC-link":"https:\/\/loczek.pl\/produkt\/feel-greens-special-line-regenerujaco-wygladzajaca-maska-peh-z-olejem-konopnym-keratyna-i-proteinami-roslinnymi\/"}};
#
# tvc_fp=[];
#
# tvc_rcp={"https:\/\/loczek.pl\/produkt\/lussoni-fryzjerska-wyciskarka-resztek-kosmetykow\/":{"tvc_id":"5915","tvc_i":"5903018917184","tvc_n":"LUSSONI - Fryzjerska wyciskarka resztek kosmetyk\u00f3w","tvc_p":"26.99","tvc_c":"Akcesoria do w\u0142os\u00f3w"},"https:\/\/loczek.pl\/produkt\/loczek-satynowy-czepek-do-spania-zabezpieczajacy-wlosy-krecone\/":{"tvc_id":"6169","tvc_i":"5903707542154","tvc_n":"LOCZEK - SATYNOWY CZEPEK DO SPANIA ZABEZPIECZAJ\u0104CY W\u0141OSY KR\u0118CONE","tvc_p":"19.99","tvc_c":"Akcesoria do w\u0142os\u00f3w,Czepki na w\u0142osy"},"https:\/\/loczek.pl\/produkt\/miksohenna-henna-mocna-naturalna-henna-nadajaca-rudej-barwy\/":{"tvc_id":"40912","tvc_i":"MIK002","tvc_n":"MIKSOHENNA HENNA -mocna, naturalna henna nadaj\u0105ca rudej barwy","tvc_p":"34.99","tvc_c":"Naturalne farbowanie,Zielarnia Loczka,Henna"},"https:\/\/loczek.pl\/produkt\/miksohenna-indygo-naturalne-indygo-nadajace-czarny-kolor\/":{"tvc_id":"40957","tvc_i":"MIK001","tvc_n":"MIKSOHENNA INDYGO - naturalne indygo nadaj\u0105ce czarny kolor","tvc_p":"34.99","tvc_c":"Naturalne farbowanie,Zielarnia Loczka,Indygo"},"https:\/\/loczek.pl\/produkt\/loczek-zestaw-spinek-z-perelkami-2szt\/":{"tvc_id":"51404","tvc_i":"5903707542123","tvc_n":"LOCZEK ZESTAW SPINEK Z PERE\u0141KAMI 2szt","tvc_p":"9.99","tvc_c":"Bez kategorii,Spinki,Ozdoby do w\u0142os\u00f3w"},"https:\/\/loczek.pl\/produkt\/loczek-zestaw-spinek-z-perelkami-2szt-3\/":{"tvc_id":"51407","tvc_i":"5903707542147","tvc_n":"LOCZEK ZESTAW SPINEK Z PERE\u0141KAMI 2szt","tvc_p":"9.99","tvc_c":"Bez kategorii,Spinki,Ozdoby do w\u0142os\u00f3w"},"https:\/\/loczek.pl\/produkt\/boots-essentials-curl-creme-krem-zel-do-lokow-cg-kopia\/":{"tvc_id":"967","tvc_i":"5045092467985","tvc_n":"BOOTS ESSENTIALS CURL CREME - krem do stylizacji","tvc_p":"44.99","tvc_c":"Produkty do stylizacji,Reanimacja,Kremy"},"https:\/\/loczek.pl\/produkt\/cantu-curl-activator-cream-aktywator-skretu\/":{"tvc_id":"1004","tvc_i":"817513010002","tvc_n":"CANTU CURL ACTIVATOR CREAM - Aktywator skr\u0119tu","tvc_p":"42.99","tvc_c":"Reanimacja,Od\u017cywki B\/S"},"https:\/\/loczek.pl\/produkt\/cantu-hydrating-nawilzajaca-odzywka-do-lokow\/":{"tvc_id":"1006","tvc_i":"817513015328","tvc_n":"CANTU Hydrating Emolientowa od\u017cywka do w\u0142os\u00f3w o ka\u017cdej porowato\u015bci","tvc_p":"34.99","tvc_c":"Od\u017cywki\/Maski"},"https:\/\/loczek.pl\/produkt\/denman-d3-szczotka-do-stylizacji-wlosow-lokow-i-fal\/":{"tvc_id":"2562","tvc_i":"2562","tvc_n":"DENMAN D3 - szczotka do stylizacji w\u0142os\u00f3w kr\u0119conych, lok\u00f3w, fal","tvc_p":"49.99","tvc_c":"Akcesoria do w\u0142os\u00f3w,Grzebienie i szczotki"},"https:\/\/loczek.pl\/produkt\/canty-stay-glue-extreme-hold-styling-gel-mocny-zel-do-stylizacji-wlosow-kreconych\/":{"tvc_id":"3838","tvc_i":"817513016318","tvc_n":"CANTU STAY GLUE MEGA HOLD STYLING GEL - mocny \u017cel do stylizacji w\u0142os\u00f3w kr\u0119conych","tvc_p":"39.99","tvc_c":"Produkty do stylizacji,\u017bele do w\u0142os\u00f3w"},"https:\/\/loczek.pl\/produkt\/complete-conditioning-co-wash\/":{"tvc_id":"4226","tvc_i":"817513010149","tvc_n":"CANTU COMPLETE CONDITIONING CO-WASH - nawil\u017caj\u0105ca od\u017cywka do mycia z bogatym sk\u0142adem","tvc_p":"36.99","tvc_c":"Od\u017cywki do mycia,Od\u017cywki\/Maski"},"https:\/\/loczek.pl\/produkt\/karelia-organica-maska-rokitnikowa-peh-objetosc-i-blask-proteiny-roslinne-i-ekstrakty-owocowe\/":{"tvc_id":"13157","tvc_i":"4620012091825","tvc_n":"Karelia Organica - maska rokitnikowa PEH, obj\u0119to\u015b\u0107 i blask, proteiny ro\u015blinne i ekstrakty owocowe","tvc_p":"16.99","tvc_c":"Od\u017cywki\/Maski"},"https:\/\/loczek.pl\/produkt\/eco-laboratorie-delikatny-szampon-dla-dzieci-1-bez-lez-biala-herbata-i-kwiat-lipy\/":{"tvc_id":"15716","tvc_i":"4627089431448","tvc_n":"Eco Laboratorie - delikatny szampon dla dzieci 1+ &quot;bez \u0142ez&quot;, bia\u0142a herbata i kwiat lipy","tvc_p":"12.99","tvc_c":"Szampony,Dla dzieci,Codzienne mycie,Szampony dla dzieci"},"https:\/\/loczek ...
#
# tvc_rdp=[];
#
# prodpage_json_ATC_link=[];
#
# tvc_pgc=[];
#
# catpage_json_ATC_link=[];
#
#
#             var items = [];
#                 //set local currencies
#             gtag("set", {"currency": tvc_lc});
#         function t_products_impre_clicks(t_json_name,t_action){
#                    t_send_threshold=0;
#                    t_prod_pos=0;
#                     t_json_length=Object.keys(t_json_name).length;
#
#             for(var t_item in t_json_name) {
#                 t_send_threshold++;
#                 t_prod_pos++;
#                 items.push({
#                     "id": t_json_name[t_item].tvc_i,
#                     "name": t_json_name[t_item].tvc_n,
#                     "category": t_json_name[t_item].tvc_c,
#                     "price": t_json_name[t_item].tvc_p,
#                 });
#
#         if(t_json_length > 6 ){
#
#                         if((t_send_threshold%6)==0){
#                             t_json_length=t_json_length-6;
#                             	gtag("event", "view_item_list", { "event_category":"Enhanced-Ecommerce",
#                                      "event_label":"product_impression_"+t_action, "items":items,"non_interaction": true});
#                                      items = [];
#                                     }
#                      }else{
#
#                        t_json_length--;
#                        if(t_json_length==0){
#                                gtag("event", "view_item_list", { "event_category":"Enhanced-Ecommerce",
#                                     "event_label":"product_impression_"+t_action, "items":items,"non_interaction": true});
#                                     items = [];
#                                 }
#         }
#                 }
#         }
#
#         //function for comparing urls in json object
#         function prod_exists_in_JSON(t_url,t_json_name,t_action){
#                                     if(t_json_name.hasOwnProperty(t_url)){
#                                         t_call_fired=true;
#                                         gtag("event", "select_content", {
#                                             "event_category":"Enhanced-Ecommerce",
#                                             "event_label":"product_click_"+t_action,
#                                             "content_type": "product",
#                                             "items": [
#                                             {
#                                                 "id":t_json_name[t_url].tvc_i,
#                                                 "name": t_json_name[t_url].tvc_n,
#                                                  "category":t_json_name[t_url].tvc_c,
#                                                  "price": t_json_name[t_url].tvc_p,
#                                             }
#                                             ],
#                                             "non_interaction": true
#                                         });
#                                    }else{
#                                    t_call_fired=false;
#                 }
#                                 return t_call_fired;
#             }
#                 function prod_ATC_link_exists(t_url,t_ATC_json_name,t_prod_data_json,t_qty){
#                     t_prod_url_key=t_ATC_json_name[t_url]["ATC-link"];
#
#                         if(t_prod_data_json.hasOwnProperty(t_prod_url_key)){
#                                 t_call_fired=true;
#                             // Enhanced E-commerce Add to cart clicks
#                                 gtag("event", "add_to_cart", {
#                                     "event_category":"Enhanced-Ecommerce",
#                                     "event_label":"add_to_cart_click",
#                                     "non_interaction": true,
#                                     "items": [{
#                                         "id" : t_prod_data_json[t_prod_url_key].tvc_i,
#                                         "name":t_prod_data_json[t_prod_url_key].tvc_n,
#                                         "category" : t_prod_data_json[t_prod_url_key].tvc_c,
#                                         "price": t_prod_data_json[t_prod_url_key].tvc_p,
#                                         "quantity" :t_qty
#                                     }]
#                                 });
#
#                         }else{
#                                    t_call_fired=false;
#                         }
#                          return t_call_fired;
#
#                 }
#
#
#                 if(tvc_fp.length !== 0){
#                     t_products_impre_clicks(tvc_fp,"fp");
#                 }
#                 if(tvc_rcp.length !== 0){
#                     t_products_impre_clicks(tvc_rcp,"rp");
#                 }
#                 jQuery("a:not([href*=add-to-cart],.product_type_variable, .product_type_grouped)").on("click",function(){
#             t_url=jQuery(this).attr("href");
#                         //home page call for click
#                         t_call_fired=prod_exists_in_JSON(t_url,tvc_fp,"fp");
#                         if(!t_call_fired){
#                             prod_exists_in_JSON(t_url,tvc_rcp,"rp");
#                         }
#                 });
#                 //ATC click
#                 jQuery("a[href*=add-to-cart]").on("click",function(){
#             t_url=jQuery(this).attr("href");
#                         t_qty=$(this).parent().find("input[name=quantity]").val();
#                              //default quantity 1 if quantity box is not there
#                             if(t_qty=="" || t_qty===undefined){
#                                 t_qty="1";
#                             }
#                         t_call_fired=prod_ATC_link_exists(t_url,homepage_json_ATC_link,tvc_fp,t_qty);
#                         if(!t_call_fired){
#                             prod_ATC_link_exists(t_url,homepage_json_ATC_link,tvc_rcp,t_qty);
#                         }
#                     });
#
#
#
# tvc_smd={"tvc_wcv":"4.4.1","tvc_wpv":"5.5.1","tvc_eev":"2.3.2","tvc_cnf":{"t_ee":"on","t_df":false,"t_gUser":true,"t_UAen":"on","t_thr":"6","t_IPA":true,"t_OptOut":false,"t_PrivacyPolicy":true}};
#  });
#   </script>
#   <script data-minify="1" src="https://loczek.pl/wp-content/cache/min/1/f51bf6e5b3fab6431b2ca15ec8dabbc9.js">
#   </script>
#   <script id="jquery-dgwt-wcas-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var dgwt_wcas = {"labels":{"category":"Kategoria","tag":"Tag","brand":"Brand","post":"Wpis","page":"Page","product_cat_plu":"Kategorie","product_tag_plu":"Tagi","product_plu":"Produkty","brand_plu":"Brands","post_plu":"Wpisy","page_plu":"Strony","sku_label":"SKU:","sale_badge":"Promocja","featured_badge":"Wyr\u00f3\u017cniony","in":"w","read_more":"continue reading","no_results":"Brak wynik\u00f3w","show_more":"Zobacz wszystkie produkty","show_more_details":"Zobacz wszystkie produkty","search_placeholder":"Szukaj produkt\u00f3w","submit":"Szukaj"},"ajax_search_endpoint":"\/?wc-ajax=dgwt_wcas_ajax_search","ajax_details_endpoint":"\/?wc-ajax=dgwt_wcas_result_details","ajax_prices_endpoint":"\/?wc-ajax=dgwt_wcas_get_prices","action_search":"dgwt_wcas_ajax_search","action_result_details":"dgwt_wcas_result_details","action_get_prices":"dgwt_wcas_get_prices","min_chars":"3","width":"auto","show_details_box":"","show_images":"1","show_price":"","show_desc":"","show_sale_badge":"","show_featured_badge":"","dynamic_prices":"","is_rtl":"","show_preloader":"1","show_headings":"","preloader_url":"","taxonomy_brands":"","img_url":"https:\/\/loczek.pl\/wp-content\/plugins\/ajax-search-for-woocommerce\/assets\/img\/","is_premium":"","overlay_mobile":"","mobile_breakpoint":"992","mobile_overlay_wrapper":"body","debounce_wait_ms":"400","send_ga_events":"1","magnifier_icon":"\t\t<svg version=\"1.1\" class=\"\" xmlns=\"http:\/\/www.w3.org\/2000\/svg\"\n\t\t     xmlns:xlink=\"http:\/\/www.w3.org\/1999\/xlink\" x=\"0px\" y=\"0px\"\n\t\t     viewBox=\"0 0 51.539 51.361\" enable-background=\"new 0 0 51.539 51.361\" xml:space=\"preserve\">\n\t\t<path d=\"M51.539,49.356L37.247,35.065c3.273-3.74,5.272-8.623,5.272-13.983c0-11.742-9.518-21.26-21.26-21.26\n\t\t\t  S0,9.339,0,21.082s9.518,21.26,21.26,21.26c5.361,0,10.244-1.999,13.983-5.272l14.292,14.292L51.539,49.356z M2.835,21.082\n\t\t\t  c0-10.176,8.249-18.425,18.425-18.425s18.425,8.249,18.425,18.425S31.436,39.507,21.26,39.507S2.835,31.258,2.835,21.082z\"\/>\n\t<\/svg>\n\t\t","custom_params":{}};
# /* ]]> */
#   </script>
#  </body>
# </html>

# %% [markdown]
# # Web scraping code

# %%
peh_categories = {"E":"Emolientowe", "P":"Proteinowe", "H":"Humektantowe"}
products_by_peh = {"E": [], "P": [], "H": []}

def get_product_details(prod_link, peh_code): 
    product_object = {}
    product_r =  requests.get(prod_link)
    product_soup = bs(product_r.content, 'lxml')

    inci_title = product_soup.find("h3", text="Skład produktu")
    if inci_title is not None:
        inci = []
        ingredients_ul = inci_title.parent.find("ul")
        if ingredients_ul is None:
            return
        
        for ingredient in ingredients_ul.find_all("li"):
            inci.append(ingredient.find("a").string)
        product_object["inci"] = ','.join(map(str, inci))
    else:
        return

    prod_title = product_soup.find('h1', {"class":"product_title entry-title"}).string
    prod_title_prep = prod_title.replace('\n', '').strip()
    product_object["title"]= prod_title_prep
    products_by_peh[peh_code].append(product_object)


def iterate_through_page_products(peh_soup, peh_code):
    products_list = peh_soup.find("ul", {"class":"products row wide"})
    print("Started iterating through products")
    for product in products_list.find_all("li"):
        product_link = product.find("a")["href"]
        get_product_details(product_link, peh_code)
    print("Finished iterating through products")

    
def iterate_through_pagination(peh_soup, peh_code):
    page_soup = peh_soup
    while True:
        iterate_through_page_products(page_soup, peh_code)
        
        next_page_a = page_soup.find("a", {"class":"next page-numbers"})
        
        if next_page_a is None:
            break
        
        next_link = next_page_a['href']
        page_r =  requests.get(next_link)
        page_soup = bs(page_r.content, 'lxml')
        
    
def handle_peh_links(peh_link, peh_code):
    peh_r =  requests.get(peh_link)
    peh_soup = bs(peh_r.content, 'lxml')
    pagination_list = peh_soup.find("ul", {"class":"page-numbers"})
    if pagination_list is not None:
        iterate_through_pagination(peh_soup, peh_code)
    else:
        iterate_through_page_products(peh_soup, peh_code)
    

for peh_code, peh_name in peh_categories.items():
    peh_link = soup.find("a", text=peh_name)['href']
    handle_peh_links(peh_link, peh_code)
    
print(products_by_peh["P"][0])
print(products_by_peh["E"][0])
print(products_by_peh["H"][0])
# Out:
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# Started iterating through products
# Finished iterating through products
# {'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimonium Chloride,Propylene Glycol,Hydrolyzed Vegetable Protein,Lawsonia Inermis (Henna) Leaf Extract,Hydrogenated Castor Oil,Parfum,Citric Acid,Magnesium Chloride,Magnesium Nitrate,Methylchloroisothiazolinone,Methylisothiazolinone,Amyl Cinnamal,Buthylphenyl Methylpropional,Limonene,Linalool', 'title': 'DABUR VATIKA TROPIKALNY KOKOS – maska do włosów bez objętości'}
# {'inci': 'Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA copolymer,Fragrance/Parfum Anise Alcohol,Linum Usitatissimum (Linseed) Seed Oil,Olea Europaea (Olive) Fruit Oil,Butyrospermum Parkii (Shea) Butter,Aminomethyl Propanol (Water Soluble),Phenoxyethanol,Benzoic Acid,Ethylhexylglycerin,Glycereth-2 Cocoate,Glycerin,Disodium Edta,Yellow 5 (CI 19140),Blue 1 (CI 42090)', 'title': 'CANTU MOISTURE RETENTION STYLING GEL- żel utrzymujący odpowiednie nawilżenie włosów kręconych i falowanych'}
# {'inci': 'Chitozan', 'title': 'Calaya – chitosan do odżywek DIY, nawilża i regeneruje włosy'}

# %%
products_by_peh
# Out:
# {'E': [{'inci': 'Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA copolymer,Fragrance/Parfum Anise Alcohol,Linum Usitatissimum (Linseed) Seed Oil,Olea Europaea (Olive) Fruit Oil,Butyrospermum Parkii (Shea) Butter,Aminomethyl Propanol (Water Soluble),Phenoxyethanol,Benzoic Acid,Ethylhexylglycerin,Glycereth-2 Cocoate,Glycerin,Disodium Edta,Yellow 5 (CI 19140),Blue 1 (CI 42090)',
#    'title': 'CANTU MOISTURE RETENTION STYLING GEL- żel utrzymujący odpowiednie nawilżenie włosów kręconych i falowanych'},
#   {'inci': 'Water (Aqua),Eau),Glycerin,Fragrance (Parfum),Butyrospermum Parkii (Shea) Butter,Cocos Nucifera (Coconut) Oil,Glycine Soja (Soybean) Seed Oil,Simmondsia Chinensis (Jojoba) Seed Oil,Aloe Barbadensis (Aloe Vera) Leaf Juice,Cocos Nucifera (Coconut) Fruit Extract,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Persea Gratissima (Avocado) Seed Oil,Vitis Vinifera (Grape) Seed Extract,Olea Europaea (Olive) Fruit Oil,Mangifera Indica (Mango) Seed Butter,Macadamia Ternifolia Seed Oil,Daucus Carota Sativa (Carrot) Seed Oil,Melia Azadirachta (Neem) Seed Oil,Argania Spinosa (Argan) Kernel Oil,Salvia Officinalis (Sage) Leaf Extract,Urtica Dioica (Nettle) Leaf Extract,Lonicera Japonica (Honeysuckle) Flower Extract,Laminara Cloustoni (Sea Kelp) Extract,Silk Amino Acids,Hydrolyzed Silk,PEG-40 Hydrogenated Castor Oil,Polyquaternium-10,Phenoxyethanol,Ethylhexylglycerin',
#    'title': 'CANTU SHEA BUTTER COCONUT OIL SHINE & HOLD MIST – mgiełka nawilżająca'},
#   {'inci': 'Water (Aqua/Eau),Polyquaternium-37,Cyclopentasiloxane,Cetearyl Alcohol,VP/Dimethylaminoethylmethacrylate Copolymer,Polyquaternium-11,Propylene Glycol Dicaprylate/Dicaprate,Fragrance (Parfum),Phenoxyethanol,Citronellol,Amyl Cinnamal,Helianthus Annuus (Sunflower) Seed Extract,Tocopherol,Linalool,C12-15 Alkyl Benzoate,Sorbitan Oleate,Panthenol,Citral,Helianthus Annuus (Sunflower) Seed Oil,Bacopa Monniera Extract,Butylphenyl\xa0Methylpropional,Simmondsia Chinensis (Jojoba) Seed Oil,PPG-1 Trideceth-6,PEG-4,Limonene,Hydroxycitronellal,Disodium Edta,VP/DMAPA Acrylates Copolymer,PEG-4 Laurate,Glycerin,Geraniol,Benzyl salicylate,iodopropynyl butylcarbamate,Chitosan,Hexyl Cinnamal,Polysorbate-60,Alcohol Denat.,Benzalkonium Chloride,Citric Acid,Butylene Glycol,PEG-4 Dilaurate',
#    'title': 'Tigi Catwalk Curls Rock Amplifier – krem stylizujący do włosów kręconych'},
#   {'inci': 'Aqua (Water),Cetearyl Alcohol,Cetrimonium Chloride,Distearoylethyl Dimonium Chloride,Myristyl Alcohol,Helianthus Annuus (Sunflower) Seed Oil,Zea Mays (Corn) Germ Oil,Citrus Limon Fruit Extract,Prunus Armeniaca (Apricot) Seed Oil,Hydrogenated Vegetable Oil,Butyrospermum Parkii (Shea) Butter,Tocopherol,Parfum (Fragrance),Citric Acid,Benzyl Alcohol,Glyceryl Laurate,Sodium Benzoate,Potassium Sorbate',
#    'title': 'INSIGHT ENERGIZING MASK – emolientowa maska do średnioporowatych i wysokoporowatych włosów'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimonium Chloride,Amodimethicone,Dimethicone,Cocos Nucifera (Coconut) Oil,Wheat Amino Acids,Soy Amino Acids,Arginine Hcl,Serine,Threonine,Trideceth-10,Polyquaternium-37,Lactic Acid,Parfum,Sodium Benzoate,Benzyl Alcohol,Potassium Sorbate,Phenoxyethanol,Linalool',
#    'title': 'DR. SANTE COCONUT HAIR Z OLEJEM KOKOSOWYM – maska emolientowa do włosów suchych i łamliwych'},
#   {'inci': 'Helianthus Annuus (Sunflower) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ SŁONECZNIKOWY – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Argania Spinosa (Argan) Kernel Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ ARGANOWY BIO – do włosów wysokoporowatych'},
#   {'inci': 'Orbignya Oleifera (Babassu) Seed Oil',
#    'title': 'MOHANI MASŁO BABASSU – do włosów niskoporowatych'},
#   {'inci': 'Aqua,Macadamia Ternifolia Seed Oil,Cetearyl Alcohol,Behentrimonium Chloride,Brassica Oleracea Italica Seed Oil,Moringa Oleifera Seed Oil,Prunus Domestica (Plum) Seed Oil,Camellia Japonica Seed Oil,Starch Hydroxypropyltrimonium Chloride,Cetrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum',
#    'title': 'Anwen Emolientowy Irys – odżywka do włosów o średniej porowatości'},
#   {'inci': 'Melia Azadirachta (Neem) Seed Oil',
#    'title': 'PHITOFILOS OLIO DI NEEM – tłoczony na zimno olej neem do włosów wysokoporowatych'},
#   {'inci': 'Cocos Nucifera (Coconut) Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ Z MIĄŻSZU KOKOSA – do włosów niskoporowatych'},
#   {'inci': 'Cannabis Sativa (Hemp) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany, lekki olej konopny, do włosów wysokoporowatych'},
#   {'inci': 'Aqua,Cetyl Alcohol,Stearyl Alcohol,Cetrimonium Chloride,PVP/VA copolymer,Phenoxyethanol,Polyquaternium-10,Parfum,Benzophenone-3,Citric Acid,Sodium Hydroxide,Linalool,Butylphenyl\xa0Methylpropional,Hydroxycitronellal,Sodium acetate,Sodium Chloride,Citronellol,Isopropyl alcohol,CI 14700',
#    'title': 'BOOTS ESSENTIALS CURL CREME – krem do stylizacji'},
#   {'inci': 'Adansonia Digitata (Baobab) Seed Oil',
#    'title': 'Your Natural Side – olej z nasion baobabu, nierafinowany'},
#   {'inci': 'Aqua,Macadamia Ternifolia Seed Oil,Cetearyl Alcohol,Behentrimonium Chloride,Brassica Oleracea Italica Seed Oil,Moringa Oleifera Seed Oil,Prunus Domestica (Plum) Seed Oil,Camellia Japonica Seed Oil,Starch Hydroxypropyltrimonium Chloride,Cetrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum',
#    'title': 'Anwen MAŁA Odżywka Emolientowy Irys do włosów o średniej porowatości'},
#   {'inci': 'Aqua,Orbignya Oleifera (Babassu) Seed Oil,Cetearyl Alcohol,Behentrimonium Chloride,Astrocaryum Murumuru Seed Butter,Caprylic/Capric Triglyceride,Starch Hydroxypropyltrimonium Chloride,Kaolin,Fucus Vesiculosus Extract,Cetrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,BHT,Parfum',
#    'title': 'EMOLIENTOWA AKACJA ANWEN odżywka do włosów o niskiej porowatości'},
#   {'inci': 'Water (Aqua/Eau),Pvp,Isobutane,Propane,Phenoxyethanol,Fragrance (Parfum),Cocamidopropyl Betaine,Caprylyl Glycol,Butane,Sodium Chloride,PEG/PPG-18/18 DIMETHICONE,Propylene Glycol,PEG/PPG-15/15 Allyl Ether Acetate,Sodium Benzoate,Alpha Isomethyl Ionone,Benzyl Benzoate,Benzyl salicylate,Butylphenyl\xa0Methylpropional,Citronallol,Hexyl Cinnamal,ISOEUGENOL,Linalool',
#    'title': 'TIGI CATWALK CURLESQUE – nieobciążająca pianka do włosów falowanych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Persea Gratissima (Avocado) Seed Oil,Butyrospermum Parkii (Shea) Butter,Cocos Nucifera (Coconut) Oil,Biotin,Bioflavonoids,Pyridoxine HCL,Linoleic Acid,Linolenic Acid,Tocopherol,Retinyl Palmitate,Tocopheryl Acetate,Panthenol,Glycerin,Cetrimonium Chloride,Propylene Glycol,Polysorbate-20,Citric Acid,Benzyl salicylate,Limonene',
#    'title': 'BARWA AWOKADO – emolientowa odżywka do włosów niskoporowatych'},
#   {'inci': 'Punica Granatum Seed Oil',
#    'title': 'Your Natural Side – wzmacniający olej z pestek granatu (nierafinowany), do włosów wysokoporowatych'},
#   {'inci': 'Cocos Nucifera (Coconut) Oil,Terminalia Chebula Extract,Emblica Officinalis (Amla) Fruit Extract,Terminalia Belirica Extract,Azadirachta Indica Leaf Extract,Centella Asiatica Plant Extract,Hedychium Spicatum Rhizome Extract,Lawsonia Inermis (Henna) Leaf Extract,Lecithin,Perfume,Aqua,Milk,Rosmarinus Officinalis (Rosemary) Leaf Essential Oil,Tocopherol Acetate (Vitamin E),Lemon Citrus Medica Oil,Butylated Hydroxy Toulene',
#    'title': 'Vatika – olejek kokosowy z ziołami'},
#   {'inci': 'Aqua/Water/Eau,Butane,VP/VA copolymer,Isobutane,Propane,Polysorbate-20,Polyquaternium-55,Pvp,Polyquaternium-4,Polyquaternium-11,Cyclopentasiloxane,Polyquaternium-7,Propylene Glycol,PPG-5-Ceteth-20,Benzophenone-4,PEG/PPG-14/4 Dimethicone,Ethylparaben,Methylparaben,Propylparaben,Imidazolidinyl Urea,Cetrimonium Chloride,Cocamidopropyl Betaine,Tetrasodium EDTA,Glycerin,sodium methylparaben,Sodium Dehydroacetate,Sorbic Acid,Parfum (Fragrance),Limonene,Linalool,Eugenol,Geraniol,Citronellol',
#    'title': 'KEMON HAIR MANYA BUILD FOAM – mocna pianka do stylizacji włosów zwiększająca objętość'},
#   {'inci': 'Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA copolymer,Fragrance,Ricinus Communis (Castor) Seed Oil,Butyrospermum Parkii (Shea) Butter,Aminomethyl Propanol (Water Soluble),Phenoxyethanol,Benzoic Acid,Ethylhexylglycerin,Glycereth-2 Cocoate,Glycerin,Disodium Edta,Hydrolyzed Soy Protein',
#    'title': 'CANTU STRENGTHENING STYLING GEL BLACK CASTOR OIL – żel wzmacniający o dużym utrwaleniu'},
#   {'inci': 'Aqua,PEG-25 Hydrogenated Castor Oil,PEG-7 Glyceryl Cocoate,Cocamidopropyl Betaine,Phenoxyethanol,Benzyl Alcohol,Parfum (Fragrance),Cetrimonium Chloride,Polyquaternium-11,Polyquaternium-55,Sodium Chloride,Panthenol (Vitamin B-5),Citric Acid,Butyrospermum Parkii (Shea) Butter,Coumarin,Benzyl Benzoate,Hexyl Cinnamal',
#    'title': 'CANTU WAVE WHIP CURLING MOUSSE – piankowy mus do fal'},
#   {'inci': 'Aqua (Water),Cetyl Alcohol,Persea Gratissima (Avocado) Seed Oil,Stearamidopropyl Dimethylamine,Glyceryl Stearate,Arachidyl Alcohol,Stearyl Alcohol,Butyrospermum Parkii (Shea) Butter,Parfum (Fragrance),Neopentyl Glycol Diheptanoate,Phenoxyethanol,Ethylhexylglycerin,Lactic Acid,Isododecane,Polyester-11,Disodium Edta,Panthenol,Benzyl salicylate,Geraniol,Hexyl Cinnamal,Linalool',
#    'title': 'CANTU AVOCADO HYDRATING CONDITIONER – odżywka emolientowa z olejem awokado i masłem shea'},
#   {'inci': 'Butyrospermum Parkii Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ Z MASŁA SHEA – do włosów wysokoporowatych, średnioporowatych i niskoporowatych'},
#   {'inci': 'Prunus Amygdalus Dulcis (Sweet Almond) Oil',
#    'title': 'Your Natural Side – nierafinowany olej ze słodkich migdałów, do włosów średnioporowatych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Cetrimonium Chloride,Linum Usitatissimum (Linseed) Seed Oil,Citric Acid,Benzophenone-3,Propylene Glycol,Parfum,Benzyl Alcohol,Methylchloroisothiazolinone,Methylisothiazolinone',
#    'title': 'KALLOS COLOR – popularna maska'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Cetrimonium Chloride,Aminopropyl Dimethicone,Isohexadecane,Parfum,Ficus Carica Fruit Extract,Citric Acid,Propylene Glycol,Benzyl Alcohol,Methylchloroisothiazolinone,Methylisothiazolinone',
#    'title': 'KALLOS FIG – emolientowa odżywka do włosów'},
#   {'inci': 'Butyrospermum Parkii (Shea) Butter',
#    'title': 'Your Natural Side – masło shea, nierafinowane, do włosów średnio- i wysokoporowatych'},
#   {'inci': 'Water (Aqua),Polyquaternium-72,Shea Butter Ethyl Esters,Polyacrylamide,C13-14 Isoparaffin,Laureth-7,Lactobacillus/Tomato Fruit Ferment Extract,Oryza Sativa (Rice) Extract,Keratin Amino Acids,Leuconostoc/Radish Rootferment Filtrate,Acyl Coenzyme A Desaturase (SCD-1),Fragrance (Parfum),Disodium Edta,Phenoxyethanol,Ethylhexylglycerin',
#    'title': 'NOT YOUR MOTHER’S CURL TALK DEFINING CREAM – emolientowy krem bez spłukiwania definiujący loki'},
#   {'inci': 'Euterpe Oleracea (Acai) Seed Oil',
#    'title': 'Your Natural Side – regenerujący olej acai (euterpa)'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Cetrimonium Chloride,Persea Gratissima (Avocado) Seed Oil,Behentrimonium Chloride,Parfum,Behenamidopropyl Dimethylamine,Dipalmitoylethyl Hydroxyethylmonium Metosulfate,Cetyl Alcohol,Stearyl Alcohol,Citric Acid,Helianthus Annuus (Sunflower) Seed Oil,Cocos Nucifera (Coconut) Oil,Linum Usitatissimum (Linseed) Seed Oil,Lactic Acid,Argania Spinosa Kernel Oil,Macadamia Ternifolia Seed Oil,Olea Europaea (Olive) Fruit Oil,Rosmarinus Officinalis (Rosemary) Leaf Extract,Propylene Glycol,Benzyl Alcohol,Methylchloroisothiazolinone',
#    'title': 'KALLOS AVOCADO – emolientowe maska do włosów falowanych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimonium Chloride,Dimethicone,Amodimethicone,Cocos Nucifera (Coconut) Oil,Wheat Amino Acids,Soy Amino Acids,Arginine Hcl,Serine,Threonine,Ppg-3 Caprylyl Ether,Polyquaternium-37,Trideceth-10,Lactic Acid,Parfum,Sodium Benzoate,Benzyl Alcohol,Potassium Sorbate,Phenoxyethanol,Linalool',
#    'title': 'DR. SANTE COCONUT HAIR – emolientowa odżywka z olejem kokosowym do włosów suchych i łamliwych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Cetrimonium Chloride,Aminopropyl Dimethicone,Isohexadecane,Parfum,Magnifera Indica Seed Oil,Citric Acid,Propylene Glycol,Benzyl Alcohol,Methylchloroisothiazolinone,Methylisothiazolinone',
#    'title': 'KALLOS MANGO – popularna maska odżywka'},
#   {'inci': 'Water (Aqua/Eau),Cetyl Alcohol,Cetrimonium Chloride,Cetearyl Alcohol,Cocos Nucifera (Coconut) Oil,Castor Oil,Cocos Nucifera (Coconut) Fruit Powder,Citrus Reticulata (Tangerine) Fruit Extract,Phytosterols,PEG-40,Parfum,Potassium Sorbate,Caprylyl Glycol,Phenoxyethanol,Abies Balsamea (Balsam Canada) Resin,Potassium Chloride,Limonene',
#    'title': 'AS I AM Coconut CoWash Cleansing Cream Conditioner – łagodna odżywka myjąca'},
#   {'inci': 'Macadamia Ternifolia Seed Oil',
#    'title': 'MOHANI OLEJ MAKADAMIA – do włosów średnioporowatych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Cetrimonium Chloride,Citric Acid,Propylene Glycol,Hydrolyzed Milk Protein,Hydrolyzed Keratin,Cyclopentasiloxane,Dimethiconol,Parfum,Benzyl Alcohol,Methylchloroisothiazolinone,Methylisothiazolinone',
#    'title': 'KALLOS KERATIN – odbudowująca odżywka do włosów'},
#   {'inci': 'Calophyllum Inophyllum (Tamanu) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ TAMANU – do włosów średnioporowatych'},
#   {'inci': 'Sclerocarya Birrea (Marula) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ MARULA – do włosów wysokoporowatych'},
#   {'inci': 'Punica Granatum Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z PESTEK GRANATU – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Octyldodecanol,Argania Spinosa Kernel Oil,Acorus Calamus Extract,Organic Avocado Extract,Isododecane and Hydrogenerated Tetradecenyl/Methylpentadecene,Zingiber Officinale Extract,Myristica Argentea Essential Oil,Cinnamonum Verum Essential Oil,Tocopherol,Perfume,Linalool,Citronellol,Limonene,Geraniol,Eugenol,Citral',
#    'title': 'ECO LABORATORIE ARGAN SPA – olej fluid do bardzo zniszczonych i farbowanych włosów'},
#   {'inci': 'Water (Aqua/Eau),Cetearyl Alcohol,Simmondsia Chinensis (Jojoba) Seed Oil,Ethylhexyl Palmitate,Olea Europaea (Olive) Fruit Oil,Glyceryl Stearate,Astrocaryum Murumuru Seed Butter,Argania Spinosa Kernel Oil,Butyrospermum Parkii (Shea) Butter,Ricinus Communis (Castor) Seed Oil,Persea Gratissima (Avocado) Seed Oil,Rosa Centifolia Seed Oil,Citrus Aurantium Amara (Neroli) Oil,Vitamin E (Tocopheryl Acetate),behentrimonium methosulfate,Cetrimonium Chloride,Biotin,Nigella Sativa (Black Cumin) Seed Oil,Trigonella Foenum-Graecum (Fenugreek) Seed Extract,Phenoxyethanol,Ethylhexylglycerin,Fragrance',
#    'title': 'BOUNCE CURL MOISTURE BALANCE LEAVE-IN CONDITIONER – emolientowa odżywka bez spłukiwania'},
#   {'inci': 'Linum Usitatissimum (Linseed) Seed Oil,Ricinus Communis (Castor) Seed Oil,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Olea Europaea (Olive) Fruit Oil,Persea Gratissima (Avocado) Seed Oil,Fragrance (Parfum)',
#    'title': 'CANTU FLAXSEED SMOOTHING OIL – mieszanka olejów z olejem lnianym i rycynowym'},
#   {'inci': 'Adansonia Digitata (Baobab) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z NASION BAOBABU – do włosów średnioporowatych'},
#   {'inci': 'Helianthus Annuus (Sunflower) Seed Oil,Argania Spinosa (Argan) Kernel Oil,Arctium Lappa (Burdock) Root Extract,BHT',
#    'title': 'Green Pharmacy, Elfa Pharm – wzmacniający olejek łopianowy na porost włosów z arganem'},
#   {'inci': 'Citrullus Vulgaris (Watermelon) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z PESTEK ARBUZA – do włosów wysokoporowatych'},
#   {'inci': 'Borago Officinalis Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z OGÓRECZNIKA LEKARSKIEGO – do włosów wysokoporowatych'},
#   {'inci': 'Prunus Amygdalus Dulcis (Sweet Almond) Oil',
#    'title': 'MOHANI OLEJ ZE SŁODKICH MIGDAŁÓW – do średnioporowatych, cienkich i delikatnych włosów'},
#   {'inci': 'Cucurbita Pepo (Pumpkin) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion dyni, do włosów wysokoporowatych'},
#   {'inci': 'Ricinus Communis (Castor) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej rycynowy na porost i do skóry głowy z łupieżem'},
#   {'inci': 'Prunus Armeniaca (Apricot) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej morelowy, do włosów średnioporowatych'},
#   {'inci': 'Moringa Oleifera Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ MORINGA – do włosów średnioporowatych'},
#   {'inci': 'Argania Spinosa Kernel Oil,Macadamia Ternifolia Seed Oil,Parfum,PEG-8,Tocopherol,Ascorbyl Palmitate,Ascorbic Acid,Citric Acid',
#    'title': 'ELFA PHARM VIS PLANTIS OLEJ ARGANOWY – wzbogacony olejem makadamia'},
#   {'inci': 'Glycerin,Water (Aqua/Eau),Butylene Glycol,PEG-8,PPG-5-Ceteth-20,Parfum,Phenoxyethanol,Carbomer,Aminomethyl Propanol (Water Soluble),Butyrospermum Parkii (Shea) Butter,Argania Spinosa Kernel Oil,Simmondsia Chinensis (Jojoba) Seed Oil,Tocopheryl Acetate,ALEURITES MOLUCCANA (KUKUI) SEED OIL',
#    'title': 'CANTU Dry Deny Moisture Seal Gel Oil – wygładzające serum do końcówek'},
#   {'inci': 'Laurus Nobilis Fruit Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ LAUROWY – do włosów niskoporowatych'},
#   {'inci': 'Coffea Arabica Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z PALONYCH NASION KAWY – do włosów wysokoporowatych'},
#   {'inci': 'Oenothera Biennis Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ Z WIESIOŁKA – do włosów wysokoporowatych'},
#   {'inci': 'Ricinus Communis (Castor) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ RYCYNOWY – do włosów niskoporowatych i średnioporowatych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Propylene Glycol,Parfum,Nigella Sativa (Black Cumin) Seed Extract,Lawsonia Inermis (Henna) Leaf Extract,Cetrimonium Chloride,Magnesium Nitrate,Methylisothiazolinone,Citric Acid',
#    'title': 'VATIKA Z CZARNUSZKĄ – emolientowa maska do włosów zniszczonych'},
#   {'inci': 'Octyldodecanol,Shea Butter Ethyl Esters,Salvia Officinalis (Sage) Leaf Extract,Organic Ginkgo Biloba Extract,Isododecane and Hydrogenerated Tetradecenyl/Methylpentadecene,Aesculus Hippocastanum Extract,Zingiber Officinale Extract,Aniba Rosaeodora Essential Oil,Geranium Essential Oil,Tocopherol,Perfume,Linalool,Citronellol,Limonene,Geraniol,Eugenol,Citral',
#    'title': 'ECO LABORATORIE KARITE SPA – olej fluid do suchych włosów'},
#   {'inci': 'Arnica Montana (Mountain Arnica) Flower Extract,Helianthus Annuus (Sunflower) Seed Oil',
#    'title': 'Your Natural Side – kojący macerat z arniki górskiej, dla wrażliwej i podrażnionej skóry głowy'},
#   {'inci': 'Simmondsia Chinensis (Jojoba) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ JOJOBA GOLD BIO – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Corylus Avellana Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z ORZECHÓW LASKOWYCH – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Rosa Moschata Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ Z NASION DZIKIEJ RÓŻY – do włosów wysokoporowatych'},
#   {'inci': 'Nigella Sativa (Black Cumin) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY, ZIMNOTŁOCZONY OLEJ Z CZARNUSZKI (CZARNEGO KMINU) – do włosów wysokoporowatych'},
#   {'inci': 'Carthamus Tinctorius Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ KROKOSZOWY BIO – do włosów wysokoporowatych'},
#   {'inci': 'Fragaria Ananassa Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z NASION TRUSKAWKI – do włosów wysokoporowatych'},
#   {'inci': 'Fragaria Ananassa Seed Oil',
#    'title': 'MOHANI OLEJ Z PESTEK TRUSKAWEK – do włosów wysokoporowatych'},
#   {'inci': 'Rubus Idaeus (Raspberry) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z NASION MALIN – do włosów wysokoporowatych'},
#   {'inci': 'Pisatcia Vera Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ PISTACJOWY – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Perilla Ocymoides Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ PERILLA Z PACHNOTKI – do włosów średnioporowatych'},
#   {'inci': 'Prunus Armeniaca (Apricot) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z PESTEK MORELI – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Persea Gratissima (Avocado) Seed Oil',
#    'title': 'MOHANI OLEJ AWOKADO – idealny do włosów średnioporowatych'},
#   {'inci': 'Aqua (Water),Polyvinylpyrrolidone,Pvp,Parfum (Fragrance),Polyquaternium-37,Butyrospermum Parkii (Shea) Butter,Phenoxyethanol,Ethylhexylglycerin,Canola Oil,Glycine Soja (Soybean) Seed Oil,Cocos Nucifera (Coconut) Fruit Extract,Cocos Nucifera (Coconut) Oil,Persea Gratissima (Avocado) Seed Oil,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Simmondsia Chinensis (Jojoba) Seed Oil,Olea Europaea (Olive) Fruit Oil,Argania Spinosa (Argan) Kernel Oil,Melia Azadirachta (Neem) Seed Oil,Daucus Carota Sativa (Carrot) Seed Oil,Macadamia Ternifolia Seed Oil,Mangifera Indica (Mango) Seed Oil,Vitis Vinifera (Grape) Seed Oil,Hydrolyzed Silk,Lonicera Japonica (Honeysuckle) Flower Extract,Macrocystis Pyrifera (Kelp) Extract,Salvia Officinalis (Sage) Leaf Extract,Urtica Dioica (Nettle) Leaf Extract,Silk Amino Acids,Aloe Barbadensis (Aloe Vera) Leaf Extract',
#    'title': 'CANTU TWIST LOCK GEL – żel do stylizacji loków'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Distearoylethyl Dimonium Chloride,Pyrus Cydonia Fruit Extract,Cucurbita Maxima Fruit Extract,Myristyl Lactate,Lauryl Alcohol,Dicaprylyl Ether,Glyceryl Laurate,Fragrance (Parfum),Citric Acid,Tocopherol,Sodium Benzoate,Potassium Sorbate,Benzyl Alcohol,Linalool,Geraniol',
#    'title': 'INSIGHT SENSITIVE SKIN MASK – emolientowa maska z pigwą i grejphfrutem'},
#   {'inci': 'Squalane',
#    'title': 'Natura Receptura – bio skwalan z oliwek, ultralekki olej – naturalne serum'},
#   {'inci': 'Prunus Persica (Peach) Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ Z PESTEK BRZOSKWINI – do włosów średnioporowatych'},
#   {'inci': 'Melia Azadirachta (Neem) Seed Oil',
#    'title': 'ETJA – NIERAFINOWANY, ZIMNOTŁOCZONY OLEJ NEEM, DO WŁOSÓW WYSOKOPOROWATYCH'},
#   {'inci': 'Cannabis Sativa (Hemp) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY, ZIMNOTŁOCZONY OLEJ KONOPNY BIO – do włosów wysokoporowatych'},
#   {'inci': 'Cucurbita Pepo (Pumpkin) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY, ZIMNOTŁOCZONY OLEJ Z PESTEK DYNI – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Linum Usitatissimum (Linseed) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ LNIANY BIO – do włosów wysokoporowatych'},
#   {'inci': 'Squalane',
#    'title': 'YOUR NATURAL SIDE SKWALAN Z OLIWEK – do włosów wysokoporowatych'},
#   {'inci': 'Sambucus\xa0Nigra Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion czarnego bzu, do włosów wysokoporowatych'},
#   {'inci': 'Caryodendron Orinocense (Cacay) Seed Oil',
#    'title': 'Your Natural Side – brazylijski olej cacay, nierafinowany'},
#   {'inci': 'Solanum Lycopersicum (Tomato) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion pomidora'},
#   {'inci': 'Argania Spinosa (Argan) Kernel Oil',
#    'title': 'Your Natural Side – zimnotłoczony olej arganowy, marokańskie złoto, do włosów średnioporowatych'},
#   {'inci': 'Persea Gratissima (Avocado) Seed Oil,Hydrogenated Vegetable Oil,Tocopherol Acetate (Vitamin E)',
#    'title': 'Your Natural Side – masło awokado, do włosów średnioporowatych'},
#   {'inci': 'Coco-Caprylate,Caprylic/Capric Triglyceride,Titanium Dioxide,Zinc Oxide,Glyceryl Behenate,Polyglyceryl-2 Dipolyhydroxystearate,Hydrated Silica,Hydrogenated Vegetable Oil,Polyhydroxystearic Acid,Polyglyceryl-3 Diisostearate,Stearic Acid,Mauritia Flexuosa (Buriti) Fruit Oil,Tocopherol,Helianthus Annuus (Sunflower) Seed Oil,Alumina,Palmitic Acid',
#    'title': 'ANTHYLLIS KREM PRZECIWSŁONECZNY DO WŁOSÓW SPF 30 – ochrona przeciwko UVA i UVB'},
#   {'inci': 'Persea Gratissima (Avocado) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ AWOKADO BIO – do włosów średnioporowatych'},
#   {'inci': 'Oenothera Biennis Oil',
#    'title': 'Your Natural Side – nierafinowany olej z wiesiołka, do wrażliwej, przetłuszczającej się skóry głowy oraz do włosów wysokoporowatych'},
#   {'inci': 'Macadamia Integrifolia Seed Oil',
#    'title': 'Your Natural Side – zimnotłoczony olej makadamia, do włosów średnioporowatych'},
#   {'inci': 'Coffea Arabica Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z zielonych nasion kawy, na porost'},
#   {'inci': 'Helianthus Annuus (Sunflower) Seed Oil,Equisetum Arvense (Horsetail) Herbs Extract,Zea Mays (Corn) Germ Oil,Arctium Lappa (Burdock) Root Extract,BHT',
#    'title': 'Green Pharmacy, Elfa Pharm – olejek łopianowy na porost i wzmocnienie włosów, z zielem skrzypu'},
#   {'inci': 'Calendula Officinalis Flower in Helianthus Annuus Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY MACERAT OLEJ Z NAGIETKA LEKARSKIEGO – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Daucus Carota in Helinathus Annuus Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY MACERAT OLEJ Z NASION MARCHWI – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Carum Petroselinum (Parsley) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion pietruszki, do przetłuszczającej się skóry głowy'},
#   {'inci': 'Rubus Fruticosus Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion jeżyn, do włosów wysokoporowatych'},
#   {'inci': 'Macadamia Ternifolia Seed Oil,Rosa Moschata Seed Oil,Parfum,PEG-8,Tocopherol,Ascorbyl Palmitate,Ascorbic Acid,Citric Acid,Citronellol,Geraniol',
#    'title': 'ELFA PHARM VIS PLANTIS OLEJ RÓŻANY – wzbogacony olejem makadamia'},
#   {'inci': 'Rubus Idaeus (Raspberry) Seed Oil',
#    'title': 'MOHANI OLEJ Z NASION MALIN – do włosów wysokoporowatych'},
#   {'inci': 'Octyldodecanol,Macadamia Integrifolia Seed Oil,Organic Sophora Japonica Flower Extract,Hamamelis Virginiana Leaf Extract,Isododecane and Hydrogenerated Tetradecenyl/Methylpentadecene,Aesculus Hippocastanum Extract,Zingiber Officinale Extract,Citrus Aurantium Essential Oil,Jasminum Essential Oil,Tocopherol,Perfume,Linalool,Citronellol,Limonene,Geraniol,Eugenol,Citral',
#    'title': 'ECO LABORATORIE MACADAMIA SPA – olej fluid do włosów cienkich i łamliwych'},
#   {'inci': 'Aqua,Pvp,Acrylates/Hydroxyesters Acrylates Copolymer,Acrylates/Steareth-20 Methacrylate Crosspolymer,Aminomethyl Propanol,Phenoxyethanol,PEG-40 Hydrogenated Castor Oil,Benzyl Alcohol,Caprylyl Glycol,Parfum,Ethylhexylglycerin,Glycerine,Sodium Benzoate',
#    'title': 'SYOSS MEN POWER HOLD – mocny żel do włosów kręconych'},
#   {'inci': 'Mangifera Indica (Mango) Seed Butter',
#    'title': 'ETJA MASŁO MANGO – do włosów niskoporowatych i średnioporowatych'},
#   {'inci': 'Theobroma Cacao (Cocoa) Seed Butter',
#    'title': 'ETJA NIERAFINOWANE ZIMNOTŁOCZONE NATURALNE MASŁO KAKAOWE – do włosów niskoporowatych i średnioporowatych'},
#   {'inci': 'ymphytum Officinale Leaf in Helianthus Annuus Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY MACERAT OLEJ Z ŻYWOKOSTU LEKARSKIEGO – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Plukenetia Volubilis (Sacha Inchi) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ INCA INCHI – do włosów średnioporowatych'},
#   {'inci': 'Prunus Amygdalus Dulcis (Sweet Almond) Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ ZE SŁODKICH MIGDAŁÓW – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Salvia Hispanica Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z NASION CHIA – do włosów wysokoporowatych'},
#   {'inci': 'Sclerocarya Birrea (Marula) Seed Oil',
#    'title': 'Your Natural Side – antystarzeniowy olej marula, nierafinowany, kwasy Omega-9'},
#   {'inci': 'Cucumis Sativus Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion ogórka, do włosów wysokoporowatych i do przetłuszczającej się skóry głowy'},
#   {'inci': 'Prunus Amygdalus Dulcis (Sweet Almond) Oil,Coffea Arabica Seed Oil,Hydrogenated Vegetable Oil,Tocopherol Acetate (Vitamin E)',
#    'title': 'Your Natural Side – masło kawowe, do włosów niskoporowatych'},
#   {'inci': 'Aqua,Cetrimonium Chloride,Cetearyl Alcohol,Myristyl Alcohol,Olea Europaea (Olive) Fruit Oil,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Lawsonia Inermis (Henna) Leaf Extract,Perfume,Magnesium Nitrate,Magnesium Chloride,Methylchloroisothiazolinone,Methylisothiazolinone,Citric Acid,CI 16255,CI 19140,CI 14720,CI 73015,CI 28440',
#    'title': 'DABUR VATIKA OLIWA Z OLIWEK – dogłębnie wzmacniająca maska do włosów'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Butyrospermum Parkii (Shea) Butter,Cucurbita Pepo (Pumpkin) Seed Oil,Behentrimonium Chloride,Brassica Oleracea Italica Seed Oil,Papaver Somniferum Seed Oil,Carthamus Tinctorius Seed Oil,Raphanus Sativus Seed Oil,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum,Citronallol,Geraniol,Linalool',
#    'title': 'Anwen MAŁA Odżywka Emolientowa Róża do włosów o wysokiej porowatości'},
#   {'inci': 'Water (Aqua),Glycerin,Polysorbate-20,Fragrance,PEG-40 Hydrogenated Castor Oil,Butyrospermum Parkii (Shea) Butter,Magnesium Sulfate,Guar Hydroxypropyl Trimonium Chloride,Citric Acid,Methylisothiazolinone,Phenoxyethanol',
#    'title': 'CANTU COMEBACK CURL NEXT DAY CURL REVITALIZER – mgiełka do reanimacji loków i fal'},
#   {'inci': 'Aqua,Pvp,Acrylates/Hydroxyesters Acrylates Copolymer,Acrylates/Steareth-20 Methacrylate Crosspolymer,Phenoxyethanol,Aminomethyl Propanol,PEG-40 Hydrogenated Castor Oil,Glycerin,DMDM Hydantoin,Panthenol,Styrax Tonkinensis (Benzoin) Resin Extract,Benzoic Acid,Ethylhexylglycerin,Linalool,Limonene,Sodium Benzoate,Buthylphenyl Methylpropional,Alpha Isomethyl Ionone,CI 60730',
#    'title': 'Żel stylizujący Schwarzkopf, Taft Looks – Irresistible Power, nr 8'},
#   {'inci': 'Butyrospermum Parkii (Shea) Butter',
#    'title': 'ETJA NIERAFINOWANE ZIMNOTŁOCZONE MASŁO SHEA – – do włosów wysokoporowatych, średnioporowatych i niskoporowatych'},
#   {'inci': 'Prunus Domestica (Plum) Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z PESTEK ŚLIWKI – do włosów średnioporowatych'},
#   {'inci': 'Arnica Montana (Mountain Arnica) Flower Extract,Helianthus Annuus (Sunflower) Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY MACERAT OLEJ Z ARNIKI GÓRSKIEJ – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Macadamia Ternifolia Seed Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ MAKADAMIA – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Limnanthes Alba Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej meadowfoam – “piana łąkowa”'},
#   {'inci': 'Mauritia Flexuosa Oil',
#    'title': 'Your Natural Side – olej z palmy buriti (Mauritia)'},
#   {'inci': 'Calophyllum Inophyllum (Tamanu) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej tamanu, do problemowej skóry głowy, skłonnej do podrażnień i łupieżu'},
#   {'inci': 'Crambe Abyssinica Seed Oil',
#    'title': 'Your Natural Side – olej abisyński (katran abisyński)'},
#   {'inci': 'Cocos Nucifera (Coconut) Oil',
#    'title': 'Your Natural Side – nierafinowany olej kokosowy, do włosów niskoporowatych'},
#   {'inci': 'Aqua,Cetrimonium Chloride,Cetearyl Alcohol,Myristyl Alcohol,Propylene Glycol,Parfum,Honey Extract,Hydrogenated Castor Oil,Marrow Extract,Egg Powder,Olea Europaea (Olive) Fruit Oil,Magnesium Nitrate,Magnesium Chloride,Methylchloroisothiazolinone,Methylisothiazolinone,Citric Acid,CI 19140,CI 42080,CI 28440,CI 16255,CI 14720',
#    'title': 'DABUR VATIKA PROTEINY JAJECZNE – maska głęboko odżywiająca'},
#   {'inci': 'Aqua (Water),Stearyl Alcohol,Cetyl Alcohol,Butyrospermum Parkii (Shea) Butter,Stearamidopropyl Dimethylamine,Glyceryl Stearate,Phenoxyethanol,Parfum (Fragrance),Neopentyl Glycol Diheptanoate,Lactic Acid,Isododecane,Ethylhexylglycerin,Polyester-11,Panthenol,Disodium Edta,Benzyl Benzoate',
#    'title': 'CANTU Hydrating Emolientowa odżywka do włosów o każdej porowatości'},
#   {'inci': 'Aqua,Pvp,Acrylates/Hydroxyesters Acrylates Copolymer,Acrylates/Steareth-20 Methacrylate Crosspolymer,Aminomethyl Propanol,Phenoxyethanol,PEG-40 Hydrogenated Castor Oil,Glycerin,Panthenol,Caffeine,Taurine,Benzotriazolyl Dodecyl p-Cresol,Parfum,DMDM Hydantoin,Benzoic Acid,Ethylhexylglycerin,Sodium Benzoate,Benzyl salicylate,Limonene,CI 60730',
#    'title': 'TAFT LOOKS V12 POWER GEL SPEED HOLD – bardzo mocny żel do stylizacji włosów falowanych i kręconych'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Butyrospermum Parkii (Shea) Butter,Cucurbita Pepo (Pumpkin) Seed Oil,Behentrimonium Chloride,Brassica Oleracea Italica Seed Oil,Papaver Somniferum Seed Oil,Carthamus Tinctorius Seed Oil,Raphanus Sativus Seed Oil,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum,Citronallol,Geraniol,Linalool',
#    'title': 'ANWEN Emolientowa Róża – odżywka do włosów o wysokiej porowatości'},
#   {'inci': 'Oryza Sativa (Rice) Bran Oil,Sesamum Indicum (Sesame ) Seed Oil,Helianthus Annuus (Sunflower) Seed Oil,Hibiscus Sabdariffa Flower Extract,Hemidesmus Indicus (Sarsaparilla) Extract,Vetiveria Zizanoides (Vetivert/Vala) Root Powder,Tocopherol Acetate (Vitamin E),Mimosa Pudica Extract,Santalum Album Extract,Onosma Hispidum Root Extract,Citrus Aurantium Amara (Neroli) Oil,Chamomilla Recuitita (Matricaria) Flower Extract,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Triticum Vulgare (Wheat) Germ Oil,Daucus Carota (Carrot) Root Extract,Geraniol,Linalool,Citronellol,Limonene',
#    'title': 'KHADI OLEJEK Z HIBISKUSEM – ajurwedyjski olejek do włosów, ciała i skóry głowy'},
#   {'inci': 'Helianthus Annuus (Sunflower) Seed Oil,Cocos Nucifera (Coconut) Oil,Ricinus Communis (Castor) Seed Oil,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Simmondsia Chinensis (Jojoba) Seed Oil,Argania Spinosa (Argan) Kernel Oil,Oryza Sativa (Rice) Bran Oil,Phyllanthus Emblica Fruit Extract,Zea Mays (Corn) Germ Oil,Tocopherol,Parfum (Fragrance)',
#    'title': 'PHITOFILOS ARMONIA ORIENTALE – mieszanka olejów do włosów'},
#   {'inci': 'Triticum Vulgare (Wheat) Germ Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ Z KIEŁKÓW PSZENICY – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Moringa Oleifera Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej moringa, do delikatnej skóry głowy'},
#   {'inci': 'Opuntia Ficus-Indica (Prickly Pear) Seed Oil',
#    'title': 'Your Natural Side – luksusowy olej z nasion opuncji figowej, nierafinowany, do włosów wysokoporowatych'},
#   {'inci': 'Passiflora Edulis Seed Oil',
#    'title': 'Your Natural Side – olej z nasion marakui (Passiflory)'},
#   {'inci': 'Rosa Canina Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej różany, z nasion dzikiej róży, do włosów wysokoporowatych'},
#   {'inci': 'Hippophaë Rhamnoides Fruit Oil (Seabuckthorn Oil)',
#    'title': 'Your Natural Side – nierafinowany olej rokitnikowy do włosów średnio- i wysokoporowatych oraz wrażliwej skóry głowy'},
#   {'inci': 'Macadamia Ternifolia Seed Oil,Hydrogenated Vegetable Oil,Tocopherol Acetate (Vitamin E)',
#    'title': 'Your Natural Side – masło makadamia, do włosów średnioporowatych'},
#   {'inci': 'Prunus Amygdalus Dulcis (Sweet Almond) Oil,Helianthus Annuus (Sunflower) Seed Oil,Prunus Armeniaca (Apricot) Seed Oil,Ricinus Communis (Castor) Seed Oil,Olea Europaea (Olive) Fruit Oil,Vitis Vinifera (Grape) Seed Oil,Tocopherol,Parfum (Fragrance)',
#    'title': 'PHITOFILOS ARMONIA MEDITERRANEA – mieszanka olejów do włosów'},
#   {'inci': 'Rubus Idaeus (Raspberry) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z nasion malin, do włosów wysokoporowatych'},
#   {'inci': 'Emblica Officinalis (Amla) Oil,Sesamum Indicum (Sesame ) Seed Oil',
#    'title': 'AYUSH AJURWEDYJSKI AMLA – olejek do ciała i włosów'},
#   {'inci': 'Butea frondosa (Tesu) Extract,Acacia Concinna (Shikakai) Fruit Extract,Hibiscus Rosa Sinensis (Chinese Rose) Flower Extract,Mangifera Indica (Mango) Seed Extract,Emblica Officinalis (Amla) Fruit Extract,Vegetable Oil',
#    'title': 'Biotique, Bio Flame of the Forest – wzmacniający olejek na porost z hibiskusem i amlą indyjską'},
#   {'inci': 'Oryza Sativa (Rice) Bran Oil,Sesamum Indicum (Sesame ) Seed Oil,Cannabis Sativa (Hemp) Seed Oil,Crambe Abyssinica Seed Oil,Sclerocarya Birrea (Marula) Seed Oil,Prunus Armeniaca (Apricot) Seed Oil,Tocopherol,Parfum (Fragrance)',
#    'title': 'PHITOFILOS ARMONIA D’AFRICA – mieszanka olejów do włosów'},
#   {'inci': 'Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA copolymer,Fragrance (Parfum),Persea Gratissima (Avocado) Seed Oil,Butyrospermum Parkii (Shea) Butter,Aminomethyl Propanol,Phenoxyethanol,Benzoic Acid,Ethylhexylglycerin,Glycereth-2 Cocoate,Glycerin,Disodium Edta,Yellow 6 (CI 15985),CI 47005',
#    'title': 'CANTU AVOCADO HYDRATING GEL FLEXIBLE HOLD- emolientowy żel stylizujący do włosów z olejem awokado i masłem shea'},
#   {'inci': 'Helianthus Annuus (Sunflower) Seed Oil,Calendula Offi\xadci\xadna\xadlis (Marigold) Flower Ex\xadtract',
#    'title': 'Natura Receptura – łagodzący macerat z kwiatów nagietka, w zimnotłoczonym oleju słonecznikowym'},
#   {'inci': 'Laurus Nobilis Fruit Oil',
#    'title': 'Your Natural Side – nierafinowany olej laurowy o balsamicznym zapachu, przeciw łupieżowi'},
#   {'inci': 'Vitis Vinifera (Grape) Seed Oil',
#    'title': 'Your Natural Side – olej winogronowy, do włosów wysokoporowatych'},
#   {'inci': 'Aqua with infusions of:,Simmondsia Chinensis (Jojoba) Seed Oil,Cananga Odorata (Ylang Ylang) Flower Essential Oil,Organic Lotus Corniculatus Flower Extract,Tamarindus Indica Leaf Extract,Mangifera Indica (Mango) Seed Oil,Acacia Arabica Bark Extract,Orchis Maculata Flower Extract,Cetearyl Alcohol,Glyceryl Stearate,Cetrimonium Chloride,Behentrimonium Chloride,Cetyl Ether,Dimethicone,Guar Hydroxypropyltrimonium Chloride,Parfum,Benzyl Alcohol,Benzoic Acid,Sorbic Acid,Citric Acid',
#    'title': 'PLANETA ORGANICA MASKA TAJSKA BLASK I SIŁA – dociąża i nadaje blask'},
#   {'inci': 'Cannabis Sativa (Hemp) Seed Oil',
#    'title': 'Dary Natury – lekki, zimnotłoczony olej konopny, do włosów wysokoporowatych'},
#   {'inci': 'Nigella Sativa (Black Cumin) Seed Oil',
#    'title': 'Dary Natury – zimnotłoczony olej z czarnuszki, do włosów wysokoporowatych i poblematycznej skóry głowy ze skłonnościami do przetłuszczania i łupieżu'},
#   {'inci': 'Trigonella Foenum - Graceum (Fenugreek) Seed Oil',
#    'title': 'Dary Natury – zimnotłoczony, ekologiczny olej z nasion kozieradki na porost włosów i wzmocnienie cebulek'},
#   {'inci': 'Aqua,Sorbitol,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Acrylates/Steareth-20 Methacrylate Crosspolymer,Glycerin,Pvp,Polysorbate-20,Carbomer,Fragrance (Parfum),Disodium Edta,Honey,Benzoic Acid,Ethylhexylglycerin,Glycereth-2 Cocoate,Yellow 5 (CI 19140),Yellow 6 (CI 15985)',
#    'title': 'MISS JESSE’S Honey Curls Curl Enhancer – miodowy żel utrwalający i definiujący'},
#   {'inci': 'Prunus Amygdalus Dulcis (Sweet Almond) Oil',
#    'title': 'ETJA NIERAFINOWANY ZIMNOTŁOCZONY OLEJ ZE SŁODKICH MIGDAŁÓW – do włosów wysokoporowatych i średnioporowatych'},
#   {'inci': 'Ribes Nigrum Seed Oil',
#    'title': 'ETJA ZIMNOTŁOCZONY OLEJ Z CZARNEJ PORZECZKI – do włosów wysokoporowatych'},
#   {'inci': 'Aqua,Carbomer,Triethanolamine,Sodium Hydroxymethylglycinate,Linum Usitatissimum (Linseed) Seed Oil,Ricinus Communis (Castor) Seed Oil,Butyrospermum Parkii (Shea) Butter,Olea Europaea (Olive) Fruit Oil,Polysorbate-20,Tetrasodium EDTA,Polyvinylpyrrolidone,Glycerin,Hydrolyzed Wheat Protein,Yellow 5 (CI 19140),Yellow 6 (CI 15985),mica,titanium dioxide and iron oxide,Parfum,Benzyl Benzoate,d-Limonene,Lilial',
#    'title': 'ECO STYLE GOLD – mocny żel do stylizacji z oliwą z oliwek i olejem rycynowym'},
#   {'inci': 'Linum Usitatissimum (Linseed) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej lniany, do włosów wysokoporowatych'},
#   {'inci': 'Oryza Sativa (Rice) Bran Oil',
#    'title': 'Your Natural Side – olej ryżowy do włosów wysoko- i średnioporowatych'},
#   {'inci': 'Citrullus Colocynthis Seed Oil',
#    'title': 'Your Natural Side – olej z pestek arbuza, do włosów wysokoporowatych'},
#   {'inci': 'Nigella Sativa (Black Cumin) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany olej z czarnuszki, redukcja łupieżu i przetłuszczania'},
#   {'inci': 'Persea Gratissima (Avocado) Seed Oil',
#    'title': 'Your Natural Side – zimnotłoczony olej awokado, do włosów średnioporowatych'},
#   {'inci': 'Prunus Domestica (Plum) Seed Oil',
#    'title': 'Your Natural Side – lekki, aromatyczny olej z pestek śliwki, do włosów średnioporów (nierafinowany)'},
#   {'inci': 'Aqua,Sapindus Mukurossi Peel Floral Water,Aesculus Hippocastanum (Horse Chestnut) Seed Extract,Salvia Officinalis (Sage) Leaf Extract,Glycerine,Behenamidopropyl Dimethylamine,Glyceryl Monostearate,Glyceryl Stearate SE,Triticum Vulgare (Wheat) Germ Oil,Oleum Rusci,Juniperus Communis Essential Oil,Parfum,Lactic Acid,Benzoic Acid,Sorbic Acid,Dehydroacetic Acid,Benzyl Alcohol',
#    'title': 'Fitokosmetik – przeciwłupieżowy balsam dziegciowy'},
#   {'inci': 'Helianthus Annuus (Sunflower) Seed Oil,Arctium Lappa (Burdock) Root Extract,Capsicum Annuum (Chili Pepper) Fruit Extract,BHT',
#    'title': 'Green Pharmacy, Elfa Pharm – olejek łopianowy na porost włosów z papryką'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimonium Chloride,Propylene Glycol,Parfum,Cereus grandiflorus (Cactus) Extract,Allium sativum (Garlic) Extract,Hydrolyzed Vegetable Protein,Methylchloroisothiazolinone,Methylisothiazolinone,Citric Acid',
#    'title': 'DABUR VATIKA DZIKI KAKTUS – maska do włosów słabych i łamliwych'},
#   {'inci': 'Hippophae Rhamnoides Water,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Crambe Abyssinica Seed Oil,Carthamus Tinctorius Seed Oil,Simmondsia Chinensis (Jojoba) Seed Oil,Pinus Siberica Cone Essential Oil,Aqua (Water),Tilia Cordata Flower Extract,Citric Acid,Glycerin,Behenamidopropyl Dimethylamine,Glyceryl Monostearate,Parfum,Lactic Acid,Benzoic Acid,Sorbic Acid,Dehydroacetic Acid,Benzyl Alcohol',
#    'title': 'Fitokosmetik – odżywczy olejek do włosów z dodatkiem nawilżającego kwiatu lipy'},
#   {'inci': 'Aqua,Pvp,Carbomer,Phenoxyethanol,Aminomethyl Propanol,PEG-40 Hydrogenated Castor Oil,Sodium Benzoate,sodium methylparaben,Dipropylene Glycol,Parfum,Benophenone-4,Tetrasodium EDTA,Benzyl salicylate,Butylphenyl\xa0Methylpropional,Limonene,Hydroxycitronellal,CI 60730,CI 17200',
#    'title': 'BOOTS ESSENTIALS EXTRA FIRM HOLD GEL – żel do stylizacji'},
#   {'inci': 'Urtica Dioica (Nettle) Seed Oil',
#    'title': 'Dary Natury – zimnotłoczony olej z nasion pokrzywy, na porost włosów'},
#   {'inci': 'Fragaria Ananassa Seed Oil',
#    'title': 'Your Natural Side – aromatyczny olej z nasion truskawki, o słodkim zapachu, do włosów wysokoporowatych (nierafinowany)'},
#   {'inci': 'Camellia Oleifera Seed Oil',
#    'title': 'Your Natural Side – kojący, nierafinowany olej kameliowy, do wrażliwej skóry głowy i do włosów wysokoporowatych'},
#   {'inci': 'Simmondsia Chinensis (Jojoba) Seed Oil',
#    'title': 'Your Natural Side – nierafinowany, złoty olej jojoba, do włosów średnioporowatych'},
#   {'inci': 'Cocos Nucifera (Coconut) Oil,Sesamum Indicum (Sesame ) Seed Oil,Milk,Nilibhrugadi Oil,Sungandhit Dravya,Trifala,Eclipta Alba,Ferriper Oxidumrubrum,Triticum Aestivum Oil,Lemon Citrus Medica Oil,Centella Asiatica,Jasminum Officinale,Datura Metel,Indigofera Tinctoria,Citrullus Colocynthis,Abrus Precatorius,Elettaria Cardamonum,Valeriana Wallichii,Pongamia Pinnata,Azadirachta Indica,Lawsonia Alba,Cedrus deodara oil (eteryczny olejek cedrowy),Anacyclus Pyrethrum,Vetiveria Zizanioides,Glycyrrhiza Glabra (Licorice) Root Extract,Quinazarine Green CI 61565',
#    'title': 'SESA – indyjski olejek na porost włosów'}],
#  'P': [{'inci': 'Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimonium Chloride,Propylene Glycol,Hydrolyzed Vegetable Protein,Lawsonia Inermis (Henna) Leaf Extract,Hydrogenated Castor Oil,Parfum,Citric Acid,Magnesium Chloride,Magnesium Nitrate,Methylchloroisothiazolinone,Methylisothiazolinone,Amyl Cinnamal,Buthylphenyl Methylpropional,Limonene,Linalool',
#    'title': 'DABUR VATIKA TROPIKALNY KOKOS – maska do włosów bez objętości'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,PPG-3 Benzyl Ether\xa0Myristate,Hydrolyzed Milk Protein,Hydrolyzed Oats,Hydrolyzed Keratin,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum',
#    'title': 'ANWEN Proteinowa Magnolia – odżywka do włosów o średniej porowatości'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,PPG-3 Benzyl Ether\xa0Myristate,Hydrolyzed Pea Protein,Keratin,Hydrolyzed Keratin,Collagen,Hydrolyzed Elastin,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum,Butylphenyl\xa0Methylpropional,Benzyl salicylate,Coumarin,Limonene,Geraniol,Linalool,Hexyl Cinnamal',
#    'title': 'ANWEN Proteinowa Orchidea – odżywka do włosów o wysokiej porowatości'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,PPG-3 Benzyl Ether\xa0Myristate,Hydrolyzed Pea Protein,Hydrolyzed Vegetable Protein PG-Propyl Silanetriol,Hydroxypropyltrimonium Hydrolyzed Wheat Protein,Camellia Sinensis (Green Tea) Leaf Extract,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum,Limonene',
#    'title': 'ANWEN Proteinowa Zielona Herbata – odżywka do włosów o średniej porowatości'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,PPG-3 Benzyl Ether\xa0Myristate,Hydrolyzed Milk Protein,Hydrolyzed Oats,Hydrolyzed Keratin,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum',
#    'title': 'Anwen MAŁA Odżywka Proteinowa Magnolia – do włosów o średniej porowatości'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,PPG-3 Benzyl Ether\xa0Myristate,Hydrolyzed Pea Protein,Keratin,Hydrolyzed Keratin,Collagen,Hydrolyzed Elastin,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum,Butylphenyl\xa0Methylpropional,Benzyl salicylate,Coumarin,Limonene,Geraniol,Linalool,Hexyl Cinnamal',
#    'title': 'Anwen MAŁA Odżywka Proteinowa Orchidea – odżywka do włosów o wysokiej porowatości'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,PPG-3 Benzyl Ether\xa0Myristate,Hydrolyzed Pea Protein,Hydrolyzed Vegetable Protein PG-Propyl Silanetriol,Hydroxypropyltrimonium Hydrolyzed Wheat Protein,Camellia Sinensis (Green Tea) Leaf Extract,Cetrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Parfum,Limonene',
#    'title': 'Anwen Mała Odżywka Proteinowa Zielona Herbata- odżywka do włosów o średniej porowatości'}],
#  'H': [{'inci': 'Chitozan',
#    'title': 'Calaya – chitosan do odżywek DIY, nawilża i regeneruje włosy'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Behentrimonium Chloride,Starch Hydroxypropyltrimonium Chloride,Solanum Tuberosum (Potato) Starch,Allium Cepa Extract,Saccharide Isomerate,Hydroxypropyltrimonium Hyaluronate,Aloe Barbadensis (Aloe Vera) Leaf Juice Powder,Cetrimonium Chloride,Glycerin,Urea,Polysorbate 80,Hydroxypropyl Guar,Citric Acid,Sodium Citrate,Phenoxyethanol,Benzoic Acid,Dehydroacetic Acid,Caprylyl Glycol,Parfum,Amyl Cinnamal,Cinnamyl Alcohol,Hydroxycitronellal',
#    'title': 'ANWEN Nawilżający Bez – odżywka do włosów o różnej porowatości'},
#   {'inci': 'Panthenol,Aqua',
#    'title': 'Calaya D-pantenol w roztworze wodnym 75% – nawilżający półprodukt do mgiełek i odżywek DIY'},
#   {'inci': 'Aqua (Water),Glycerin,Emblica Officinalis (Amla) Fruit Extract,Betaine,Cetrimonium Chloride,Inulin,Panthenol,Guar Hydroxypropyltrimonium Chloride,Ubiquinone\xa0(coenzyme Q10),Tocopherol Acetate (Vitamin E),Perfume,Benzyl Alcohol,Caprylyl Glycol,C12-C15 Alkyl Benzoate,Sodium Benzoate,Potassium Sorbate',
#    'title': 'Eco Laboratorium – serum do włosów, mgiełka, ochrona koloru, indyjska amla'},
#   {'inci': 'Alcea Rosea Nigra Flower',
#    'title': 'Dary Natury – kwiat czarnej malwy, na kojące płukanki DIY'},
#   {'inci': 'Propylene Glycol,Aqua,Rubus Idaeus (Raspberry) Fruit Extract,Phenoxyethanol,Methylparaben',
#    'title': 'Calaya – płynny ekstrakt z maliny'},
# ...
#   {'inci': 'Water (Aqua/Eau),Sodium Hyaluronate,Hyaluronic Acid,Dehydroacetic Acid,Benzyl Alcohol',
#    'title': 'YOUR NATURAL SIDE KWAS HIALURONOWY 3% – odżywcze serum nawilżające'},
#   {'inci': 'Aqua (Water),Glycerin,Aloe Barbadensis (Aloe Vera) Leaf Extract,Xanthan Gum,Polyglyceryl-3 Caprate,Punica Granatum (Pomegranate) Fruit Extract,Argania Spinosa (Argan) Kernel Oil,Linum Usitatissimum (Linseed) Seed Oil,Cocos Nucifera (Coconut) Oil,Citrus Aurantium Bergamia (Bergamot) Fruit Oil,Citrus Grandis (Grapefruit) Seed Extract,Tilia Cordata (Linden) Flower Oil,Litsea Cubeba (May Chang) Oil,Magnolia Flower Oil,Magnolia Leaf Oil,Citrus Nobilis (Mandarin Red) Peel Oil,Origanum Majorana (Marjoram Sweet) Leaf Oil,Citrus Aurentium Dulcis (Orange) Peel Extract,Palmarosa Leaf Oil,Patchouli Leaf Oil,Rosmarinus Officinalis (Rosemary) Leaf Essential Oil,Mentha Piperita (Peppermint) Leaf Essential Oil,Styrax Tonkinensis (Benzoin) Resin Extract,Ricinus Communis (Castor) Seed Oil,Benzyl Alcohol,Dehydroacetic Acid,Limonene,Linalool,Geraniol,Citral,Benzyl Benzoate',
#    'title': 'BOUCLEME CURL DEFINING GEL – żel do stylizacji definiujący loki'},
#   {'inci': 'Water,Glycerin,Propanediol,Fragrance (Parfum),Polyquaternium-10,Stearalkonium Chloride,Stearyl Alcohol,Butyrospermum Parkii (Shea) Butter,Cocos Nucifera (Coconut) Oil,Aloe Barbadensis (Aloe Vera) Leaf Juice,Simmondsia Chinensis (Jojoba) Seed Oil,Glycine Soja (Soybean) Seed Oil,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Persea Gratissima (Avocado) Seed Oil,Olea Europaea (Olive) Fruit Oil,Mangifera Indica (Mango) Seed Butter,Argania Spinosa (Argan) Kernel Oil,Melia Azadirachta (Neem) Seed Oil,Daucus Carota Sativa (Carrot) Seed Oil,Lonicera Japonica (Honeysuckle) Flower Extract,Laminara Cloustoni (Sea Kelp) Extract,Salvia Officinalis (Sage) Leaf Extract,Macadamia Ternifolia Seed Oil,Vitis Vinifera (Grape) Seed Extract,Urtica Dioica (Nettle) Leaf Extract,Silk Amino Acids,Cetyl Alcohol,Cetearyl Alcohol,Polysorbate-60,Phenoxyethanol,Ethylhexylglycerin',
#    'title': 'MINI CANTU CURL ACTIVATOR CREAM – Aktywator skrętu'},
#   {'inci': 'botanical infusion of water,Equisetum Arvense (Horsetail) Herbs Extract,Chamomilla Recuitita (Matricaria) Flower Extract,Urtica Dioica (Nettle) Leaf Extract,Aloe Barbadensis (Aloe Vera) Leaf Juice,agave nectar extract,tocopheryl acetate (vitamin e),pectic,Citric Acid,Potassium Sorbate,Fragrance',
#    'title': 'KINKY CURLY CURLING CUSTARD – żel do stylizacji loków i fal'},
#   {'inci': 'Hordeum Powder',
#    'title': 'MyVita – młody jęczmien w proszku, dla zdrowia i witalności włosów'},
#   {'inci': 'Aqua (Water),Glycerin,Lauryl Lactate,Behenamidopropyl Dimethylamine,Althaea Officinalis (Marshmallow) Root Extract,Linum Usitatissimum (Linseed) Seed Oil,Medicago Sativa Leaf Extract,Hamamelis Virginiana Leaf Extract,Panicum Miliaceum Seed Extract,Oryza Sativa (Rice) Extract,Urea,Tetrasodium Glutamate Diacetate,Propanediol,Phenethyl Alcohol,Lactic Acid,Undecyl Alcohol,Benzyl Alcohol,Parfum (Fragrance)',
#    'title': 'PHITOFILOS SPRAY ANTICRESPO CON ALTEA – nawilżająco-wygładzająca mgiełka do włosów z olejem lnianym i wyciągiem z prawoślazu'},
#   {'inci': 'Avena Sativa Powder',
#    'title': 'Natura Wita – sproszkowane ziele owsa, do maseczek DIY, źródło protein i wzmacniającej krzemionki'},
#   {'inci': 'Glycerin,Royal Jelly',
#    'title': 'Calaya – odżywcze mleczko pszczele do odżywek DIY'},
#   {'inci': 'Humulus Lupulus Cone Poder,Kaolin,Matricaria Chamomilla Flower Powder,Arctium Lappa Root Powder,Calendula Officinalis Flower Powder,Hypericum Perforatum Powder,Betula Alba Leaf Powder,Equisetum Arvense Leaf Powder,Acorus Calamus Root Powder,Lactic Acid',
#    'title': 'DNC – chmielowa maska na porost DIY, 100% ziołowa'},
#   {'inci': 'Linum Usitatissimum Seed',
#    'title': 'Dary Natury – nasiona lnu (siemię lniane), na nawilżąjcy żel'},
#   {'inci': 'Viola Tricolor Herbs',
#    'title': 'NaturaVita – ziele fiołka trójbarwnego, na płukanki łagodząco – wzmacniające DIY'},
#   {'inci': 'Althaeae Officinalis Root',
#    'title': 'Herbapol – korzeń prawoślazu, na nawilżający żel DIY'},
#   {'inci': 'Aqua,Sodium Hyaluronate,Phenoxyethanol,Ethylhexylglycerin',
#    'title': 'MyVita – nawilżający kwas hialuronowy 3%, potrójny, 30 ml'},
#   {'inci': 'Modificated aqua from Rabka Zdrój,Aloe Barbadensis (Aloe Vera) Leaf Extract,Propylene Glycol,Glycerin,Panthenol,Triethanolamine,Allantoin,Polysorbate-20,DMDM Hydantoin',
#    'title': 'GorVita – nawilżający żel aloesowy, na bazie wody z Uzdrowiska Rabka'},
#   {'inci': 'Rosa Flower Buds',
#    'title': 'Dary Natury – suszone, EKO pączki kwiatów róży, ukojenie i nawilżenie dla podrażnionej skóry'},
#   {'inci': 'Trigonella Foenum-Graecum (Fenugreek) Seed Extract',
#    'title': 'Dary Natury – kozieradka na porost i wzmocnienie włosów, nasiona mielone'},
#   {'inci': 'Trigonella Foenum-Graecum (Fenugreek) Seed Extract',
#    'title': 'Dary Natury – kozieradka na porost i wzmocnienie włosów, nasiona mielone, EKO'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Glycerin,Isopropyl Myristate,Stearamidopropyl Dimethylamine,Glycine Soja (Soybean) Seed Oil,Prunus Amygdalus Dulcis Seed Extract / Sweet Almond Seed Extract,Agave Tequilana Leaf Extract,Aloe Barbadensis (Aloe Vera) Leaf Juice,Sodium Hydroxide,Helianthus Annuus (Sunflower) Seed Oil,Coco-Caprylate,Hydroxypropyl Guar Hydroxypropyltrimonium Chloride,Caprylyl Glycol,Citric Acid,Xanthan Gum,Tartaric Acid,Cetyl Esters,Potassium Sorbate,Sodium Benzoate,Salicylic Acid,Dehydroacetic Acid,Linalool,Parfum',
#    'title': 'GARNIER Ultimate Blends Almond Milk Normal Hair Conditioner – odżywka do mycia i emulgowania'},
#   {'inci': 'Eucalyptus Globulus Leaf Water',
#    'title': 'YOUR NATURAL SIDE HYDROLAT EUKALIPTUSOWY – do problematycznej skóry głowy, skłonnej do łupieżu, przetłuszczającej się'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Glycerin,Behenamidopropyl Dimethylamine,Trigonella Foenum-Graecum (Fenugreek) Seed Extract,Raphanus Sativus Root Extract,Equisetum Arvense (Horsetail) Herbs Extract,Cetrimonium Chloride,Niacinamide,Butyrospermum Parkii (Shea) Butter,Undecane,Tridecane,Tocopherol,Lactic Acid,Parfum,Sodium Benzoate,Potassium Sorbate,Hexyl Cinnamal,Linalool,Limonene',
#    'title': 'ELFA PHARM VIS PLANTIS KOZIERADKA MASKA DO WŁOSÓW OSŁABIONYCH Z TENDENCJĄ DO WYPADANIA – z kozieradką, czarną rzepą i skrzypem polnym'},
#   {'inci': 'Aqua,Propylene Glycol,Potassium Sorbate,Rose Extract,Citric Acid,Citronellol,Geraniol',
#    'title': 'DABUR WODA RÓŻANA – nawilżający podkład pod olej'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Glycerin,Ceteareth-3,Behentrimonium Chloride,Crambe Abyssinica Seed Oil,Crocus Sativus Oil,Zingiber Officinale Essential Oil,Borago Officinalis Seed Oil,Santalum Album Еssential Оil,Glycine Soja (Soybean) Glycerides,Butyrospermum Parkii (Shea) Butter,Laurus Nobilis Fruit Oil,Myrtus Communis Oil,Hydroxyethylcellulose,Silicone Quaternium-17,Trideceth-7,Trideceth-5,Capsicum Annuum (Chili Pepper) Fruit Extract,Phenoxyethanol,Ethylhexylglycerin,Tetrasodium EDTA,Citric Acid,Parfum,CI 15985,CI 19140',
#    'title': 'LUXURY OILS – NAWILŻAJĄCA MASKA DO WŁOSÓW WZMOCNIENIE I WZROST'},
#   {'inci': 'Aqua,Sapindus Mukurossi Peel Floral Water,Brassica Alba Seed Extract,Honey Extract,Malva Sylvestris (Mallow) Flower Extract,Glycerine,Behenamidopropyl Dimethylamine,Glyceryl Monostearate,Glyceryl Stearate SE,Triticum Vulgare (Wheat) Germ Oil,Hibiscus Flower Extract,Parfum,Lactic Acid,Benzoic Acid,Sorbic Acid,Dehydroacetic Acid,Benzyl Alcohol',
#    'title': 'Fitokosmetik, gorczycowy balsam na porost, z miodem i malwą'},
#   {'inci': 'Water (Aqua/Eau),Pvp,Glycerin,PEG-4,Xanthan Gum,Carbomer,Argania Spinosa Kernel Oil,Hydroxyethylcellulose,Caprylyl Glycol,Aminomethyl Propanol (Water Soluble),Parfum,Citronellol,Geraniol,Limonene,Linalool,Phenoxyethanol,Yellow 5 (CI 19140),Red 4 (CI 14700)',
#    'title': 'CREME OF NATURE MAXIMUM-HOLD STYLING SNOT – mocno utrwalający żel wzbogacony olejem arganowym'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Glycerin,Behenamidopropyl Dimethylamine,Isopropyl Palmitate,Trigonella Foenum-Graecum (Fenugreek) Seed Extract,Equisetum Arvense (Horsetail) Herbs Extract,Raphanus Sativus Root Extract,Butyrospermum Parkii (Shea) Butter,Cetrimonium Chloride,Niacinamide,Lactic Acid,Parfum,Sodium Benzoate,Potassium Sorbate,Hexyl Cinnamal,Limonene,Linalool',
#    'title': 'ELFA PHARM VIS PLANTIS KOZIERADKA ODŻYWKA DO WŁOSÓW OSŁABIONYCH Z TENDENCJĄ DO WYPADANIA – humektantowa, nawilżająca z kozieradką, czarną rzepą i skrzypem polnym'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Glycerin,Cetyl Alcohol,Isopropyl Palmitate,Nigella Sativa (Black Cumin) Seed Extract,Gossypium Herbaceum Extract,Linum Usitatissimum (Linseed) Seed Extract,behentrimonium methosulfate,Quaternium-80,C10-40 Isoalkylamidopropylethyldimonium Ethosulfate,Cetrimonium Chloride,Gossypium Herbaceum Seed Oil,Propylene Glycol,Lactic Acid,Parfum,Sodium Benzoate,Potassium Sorbate',
#    'title': 'ELFA PHARM VIS PLANTIS CZARNUSZKA ODŻYWKA DO WŁOSÓW CIENKICH I POZBAWIONYCH OBJĘTOŚCI – humektantowa, nawilżająca'},
#   {'inci': 'Aqua,Glycerin,Sclerocarya Birrea (Marula) Seed Oil,PHOSPHOLIPIDS,Polyquaternium-37,Parfum,Propylene Glycol Dicaprylate/Dicaprate,Phenoxyethanol,Glycine Soja (Soybean) Seed Oil,Ceteareth-20,Cetrimonium Chloride,Ethylhexylglycerin,Ppg1,Shea Butter Ethyl Esters,GLYCOLIPIDS,Limonene,Aloe Barbadensis (Aloe Vera) Leaf Juice,Panthenol,Glycine Soja (Soybean) Sterols,Coumarin,Butylphenyl\xa0Methylpropional,Linalool,Potassium Sorbate,Sodium Benzoate',
#    'title': 'ONLY CURLS Hydrating Curl Creme – nawadniający krem do stylizacji loków i fal'},
#   {'inci': 'Rosa Damascena Petal Flower Water',
#    'title': 'MOHANI HYDROLAT RÓŻANY – Nawilżająca mgiełka pod olej dla każdej porowatości'},
#   {'inci': 'Hippophae Rhamnoides Water,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Crambe Abyssinica Seed Oil,Carthamus Tinctorius Seed Oil,Simmondsia Chinensis (Jojoba) Seed Oil,Pinus Siberica Cone Essential Oil,Aqua (Water),Tilia Cordata Flower Extract,Citric Acid,Glycerin,Behenamidopropyl Dimethylamine,Glyceryl Monostearate,Parfum,Lactic Acid,Benzoic Acid,Sorbic Acid,Dehydroacetic Acid,Benzyl Alcohol',
#    'title': 'Fitokosmetik – odżywczy olejek do włosów z dodatkiem nawilżającego kwiatu lipy'},
#   {'inci': 'Aqua,Cetearyl Alcohol,Glycerin,Behenamidopropyl Dimethylamine,Isopropyl Palmitate,Glycyrrhiza Glabra (Licorice) Root Extract,Tilia Cordata Leaf Extract,Butyrospermum Parkii (Shea) Butter,Althaea Officinalis (Marshmallow) Root Extract,Cetrimonium Chloride,Helianthus Annuus (Sunflower) Seed Oil,Panthenol,Lactic Acid,Parfum,Sodium Benzoate,Potassium Sorbate,Benzyl salicylate,Hexyl Cinnamal,Linalool',
#    'title': 'ELFA PHARM VIS PLANTIS LUKRECJA ODŻYWKA DO WŁOSÓW SUCHYCH I MATOWYCH – Humektantowa, nawilżająca'},
#   {'inci': 'Water (Aqua/Eau),Glycerin,Carbomer,Aminomethyl Propanol (Water Soluble),Vitis Vinifera (Grape) Seed Oil,Phenoxyethanol,Pvp,Parfum,Hydrolyzed Wheat Protein,Ethylhexylglycerin,Tetrasodium EDTA,Potassium Sorbate,Tocopherol,Rice Amino Acids,Althaea Officinalis (Marshmallow) Root Extract,Prunus Amygdalus Dulcis (Sweet Almond) Oil,Sodium Benzoate,Dehydroacetic Acid,Benzyl salicylate,Linalool,Geraniol',
#    'title': 'AUNT JACKIE’S ICE CURLS GLOSSY CURLING JELLY – nabłyszczający żel stylizujący do włosów wysokoporowatych'},
#   {'inci': 'Aqua,Equisetum Arvense (Horsetail) Herbs Extract,Chamomilla Recuitita (Matricaria) Flower Extract,Urtica Dioica (Nettle) Leaf Extract,Althaea Officinalis (Marshmallow) Root Extract,Aloe Barbadensis (Aloe Vera) Leaf Juice,agave nectar extract,tocopheryl acetate (vitamin e),Pectin,Citric Acid,Potassium Sorbate,natural fragrance',
#    'title': 'KINKY CURLY CURLING CUSTARD WERSJA DUŻA – żel do stylizacji loków i fal'},
#   {'inci': 'Water,VP/VA copolymer,Glycerin,PEG-7 Glyceryl Cocoate,Citrus Aurentium Dulcis (Orange) Peel Extract,Melissa Officinalis Leaf Extract,Humulus Lupulus (Hops) Extract,Cymbopogon Schoenanthus Leaf (Extract,Chamomilla Recuitita (Matricaria) Flower Extract,Achillea Millefolium Extract,PEG-40 Hydrogenated Castor Oil,DMDM Hydantoin,Aminomethyl Propanol,Acrylates/C10-30 Alykl Acrylate Crosspolymer,Fragrance (Parfum),Red 33 (CI 17200),Yellow 5 (CI 19140)',
#    'title': 'DEVACURL ARC ANGEL GEL – żel do stylizacji loków i fal'},
#   {'inci': 'Water (Aqua),Eau),Glycerin,Propylene Glycol,Carbomer,Phenoxyethanol,Polysorbate-20,Aminomethyl Propanol,PEG-75 Lanolin,Ethylhexylglycerin,Fragrance (Parfum),Tetrasodium EDTA,Aloe Barbadensis (Aloe Vera) Leaf Extract,Polyquaternium-11,Benzyl Benzoate',
#    'title': 'CURLY KIDS CURLY GEL CURL MOISTURIZER – żel nawilżający do stylizacji dla dzieci'},
#   {'inci': 'Glycerin,Water,Triethanolamine,Fragrance/Parfum Anise Alcohol,Betaine,Acetamide MEA,Citrus Reticulata (Tangerine) Fruit Extract,Coumarin,Ceteareth-25,Cocos Nucifera (Coconut) Fruit Powder,Butyrospermum Parkii (Shea) Butter,Ricinus Communis (Castor) Seed Oil,TBHQ,Linalool,Caprylyl Glycol,Beta Vulgaris (Beet) Root Extract,Phenoxyethanol,Cocos Nucifera (Coconut) Oil,Phytosterols,Potassium Sorbate,Helianthus Annuus (Sunflower) Seed Oil,Laureth-23,Limonene,Carbomer,Emblica Officinalis Fruit Powder',
#    'title': 'AS I AM TWIST DEFINING CREAM – krem do stylizacji'},
#   {'inci': 'Mangifera Indica (Mango) Seed Extract,organic slippery elm,organic lemongrass,Althaea Officinalis (Marshmallow) Root Extract,Cetyl Alcohol,behentrimonium methosulfate,Citric Acid,Phenoxyethanol,natural fragrance',
#    'title': 'KINKY CURLY KNOT TODAY – odżywka bez spłukiwania'},
#   {'inci': 'Water,Glycerin,Xanthan Gum,Hydrogenated Coconut Oil,Hydroxyethylcellulose,chondrus crispus,VP/VA copolymer,Potassium Sorbate,Fragrance,Citric Acid,Panthenol,Aloe Barbadensis (Aloe Vera) Leaf Juice',
#    'title': 'CURLY KIDS MIXED HAIR CUSTARD FOR KIDS – nawilżający krem stylizujący włosy'},
#   {'inci': 'Aqua,Glycerin,Panthenol,Glycine,Arctium Lappa (Burdock) Root Extract,Urtica Dioica (Nettle) Leaf Extract,Humulus Lupulus Extract,Capsicum Annuum (Chili Pepper) Fruit Extract,Tocopheryl Acetate,Betaine,PEG-40 Hydrogenated Castor Oil,Trideceth-9,Carbomer,Potassium Hydroxide,Benzoic Acid,Sorbic Acid,Dehydroacetic Acid,Benzyl Alcohol,Parfum,CI 15980,CI 42090,CI 19140',
#    'title': 'FLORESAN AKTYWNE SERUM WCIERKA PRZECIW ŁYSIENIU – ŁOPIAN, PAPRYCZKA CHILI, POKRZYWA'},
#   {'inci': 'Aloe Barbadensis (Aloe Vera) Leaf Juice,Nelumbium Speciosum Flower Extract,Centella Asiatica Leaf Extract,Bambusa Vulgaris Leaf/Stem Extract,Cucumis Sativus (Cucumber) Fruit Extract,Zea Mays (Corn) Leaf Extract,Brassica Oleracea Capitata (Cabbage) Leaf Extract,Citrullus Lanatus (Watermelon) Fruit Extract,PEG - 60 Hydrogenated Castor Oil,Sodium Polyacrylate,Carbomer,Triethanolamine,Fragrance,Phenoxyethanol',
#    'title': 'Holika Holika – wielofunkcyjny, nawilżający żel aloesowy do włosów i skóry głowy'},
#   {'inci': 'Aqua,Sodium Hyaluronate,Benzyl Alcohol,Dehydroacetic Acid',
#    'title': 'Calaya – nawilżający żel hialuronowy, 2% (50 ml)'},
#   {'inci': 'Aqua,Sapindus Mukurossi Peel Floral Water,Humulus Lupulus Extract,Malt Extract,Chamomilla Recuitita (Matricaria) Flower Extract,Glycerin,Behenamidopropyl Dimethylamine,Glyceryl Monostearate,Glyceryl Stearate SE,Triticum Vulgare (Wheat) Germ Oil,Hibiscus Flower Extract,Parfum,Lactic Acid,Benzoic Acid,Sorbic Acid,Dehydroacetic Acid,Benzyl Alcohol',
#    'title': 'FITOKOSMETIK DROŻDŻE PIWNE AKTYWATOR WZROSTU – nawilżający balsam do włosów'},
#   {'inci': 'Linum Usitatissimum (Linseed) Seed Extract,Glycerin,Simmondsia Chinensis (Jojoba) Seed Oil,Aloe Barbadensis (Aloe Vera) Leaf Juice Powder,Magnesium Sulfate,Benzoic Acid,Dehydroacetic Acid,Phenoxyethanol',
#    'title': 'JESSICURL Rockin’ Ringlets Styling Potion No Fragrance – żel do podkreślenia skrętu'},
#   {'inci': 'Aqua (Water),Linum Usitatissimum (Linseed) Seed Extract,Glycerin,Simmondsia Chinensis (Jojoba) Seed Oil,Aloe Barbadensis (Aloe Vera) Leaf Juice Powder,Magnesium Sulfate,Benzoic Acid,Dehydroacetic Acid,Phenoxyethanol',
#    'title': 'JESSICURL Gelebration Spray – krem do stylizacji fal i loków'}]}

# %%
products_by_peh.keys()
# Out:
# dict_keys(['E', 'P', 'H'])

# %% [markdown]
# # Convert data to df pandas object

# %%
df_e = pd.DataFrame(products_by_peh['E'])
df_e['peh_class'] = list(products_by_peh.keys())[0]
df_e
# Out:
#                                                   inci  \
# 0    Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA...
# 1    Water (Aqua),Eau),Glycerin,Fragrance (Parfum),...
# 2    Water (Aqua/Eau),Polyquaternium-37,Cyclopentas...
# 3    Aqua (Water),Cetearyl Alcohol,Cetrimonium Chlo...
# 4    Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimo...
# ..                                                 ...
# 164                    Urtica Dioica (Nettle) Seed Oil
# 165                         Fragaria Ananassa Seed Oil
# 166                         Camellia Oleifera Seed Oil
# 167             Simmondsia Chinensis (Jojoba) Seed Oil
# 168  Cocos Nucifera (Coconut) Oil,Sesamum Indicum (...
#
#                                                  title peh_class
# 0    CANTU MOISTURE RETENTION STYLING GEL- żel utrz...         E
# 1    CANTU SHEA BUTTER COCONUT OIL SHINE & HOLD MIS...         E
# 2    Tigi Catwalk Curls Rock Amplifier – krem styli...         E
# 3    INSIGHT ENERGIZING MASK – emolientowa maska do...         E
# 4    DR. SANTE COCONUT HAIR Z OLEJEM KOKOSOWYM – ma...         E
# ..                                                 ...       ...
# 164  Dary Natury – zimnotłoczony olej z nasion pokr...         E
# 165  Your Natural Side – aromatyczny olej z nasion ...         E
# 166  Your Natural Side – kojący, nierafinowany olej...         E
# 167  Your Natural Side – nierafinowany, złoty olej ...         E
# 168            SESA – indyjski olejek na porost włosów         E
#
# [169 rows x 3 columns]

# %%
df_p = pd.DataFrame(products_by_peh['P'])
df_p['peh_class'] = list(products_by_peh.keys())[1]
df_p
# Out:
#                                                 inci  \
# 0  Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimo...
# 1  Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
# 2  Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
# 3  Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
# 4  Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
# 5  Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
# 6  Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
#
#                                                title peh_class
# 0  DABUR VATIKA TROPIKALNY KOKOS – maska do włosó...         P
# 1  ANWEN Proteinowa Magnolia – odżywka do włosów ...         P
# 2  ANWEN Proteinowa Orchidea – odżywka do włosów ...         P
# 3  ANWEN Proteinowa Zielona Herbata – odżywka do ...         P
# 4  Anwen MAŁA Odżywka Proteinowa Magnolia – do wł...         P
# 5  Anwen MAŁA Odżywka Proteinowa Orchidea – odżyw...         P
# 6  Anwen Mała Odżywka Proteinowa Zielona Herbata-...         P

# %%
df_h = pd.DataFrame(products_by_peh['H'])
df_h['peh_class'] = list(products_by_peh.keys())[2]
df_h
# Out:
#                                                   inci  \
# 0                                             Chitozan
# 1    Aqua,Cetearyl Alcohol,Behentrimonium Chloride,...
# 2                                       Panthenol,Aqua
# 3    Aqua (Water),Glycerin,Emblica Officinalis (Aml...
# 4                             Alcea Rosea Nigra Flower
# ..                                                 ...
# 122  Aloe Barbadensis (Aloe Vera) Leaf Juice,Nelumb...
# 123  Aqua,Sodium Hyaluronate,Benzyl Alcohol,Dehydro...
# 124  Aqua,Sapindus Mukurossi Peel Floral Water,Humu...
# 125  Linum Usitatissimum (Linseed) Seed Extract,Gly...
# 126  Aqua (Water),Linum Usitatissimum (Linseed) See...
#
#                                                  title peh_class
# 0    Calaya – chitosan do odżywek DIY, nawilża i re...         H
# 1    ANWEN Nawilżający Bez – odżywka do włosów o ró...         H
# 2    Calaya D-pantenol w roztworze wodnym 75% – naw...         H
# 3    Eco Laboratorium – serum do włosów, mgiełka, o...         H
# 4    Dary Natury – kwiat czarnej malwy, na kojące p...         H
# ..                                                 ...       ...
# 122  Holika Holika – wielofunkcyjny, nawilżający że...         H
# 123   Calaya – nawilżający żel hialuronowy, 2% (50 ml)         H
# 124  FITOKOSMETIK DROŻDŻE PIWNE AKTYWATOR WZROSTU –...         H
# 125  JESSICURL Rockin’ Ringlets Styling Potion No F...         H
# 126  JESSICURL Gelebration Spray – krem do stylizac...         H
#
# [127 rows x 3 columns]

# %%
frames = [df_e, df_p, df_h]

df_npk_final = pd.concat(frames)
df_npk_final
# Out:
#                                                   inci  \
# 0    Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA...
# 1    Water (Aqua),Eau),Glycerin,Fragrance (Parfum),...
# 2    Water (Aqua/Eau),Polyquaternium-37,Cyclopentas...
# 3    Aqua (Water),Cetearyl Alcohol,Cetrimonium Chlo...
# 4    Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimo...
# ..                                                 ...
# 122  Aloe Barbadensis (Aloe Vera) Leaf Juice,Nelumb...
# 123  Aqua,Sodium Hyaluronate,Benzyl Alcohol,Dehydro...
# 124  Aqua,Sapindus Mukurossi Peel Floral Water,Humu...
# 125  Linum Usitatissimum (Linseed) Seed Extract,Gly...
# 126  Aqua (Water),Linum Usitatissimum (Linseed) See...
#
#                                                  title peh_class
# 0    CANTU MOISTURE RETENTION STYLING GEL- żel utrz...         E
# 1    CANTU SHEA BUTTER COCONUT OIL SHINE & HOLD MIS...         E
# 2    Tigi Catwalk Curls Rock Amplifier – krem styli...         E
# 3    INSIGHT ENERGIZING MASK – emolientowa maska do...         E
# 4    DR. SANTE COCONUT HAIR Z OLEJEM KOKOSOWYM – ma...         E
# ..                                                 ...       ...
# 122  Holika Holika – wielofunkcyjny, nawilżający że...         H
# 123   Calaya – nawilżający żel hialuronowy, 2% (50 ml)         H
# 124  FITOKOSMETIK DROŻDŻE PIWNE AKTYWATOR WZROSTU –...         H
# 125  JESSICURL Rockin’ Ringlets Styling Potion No F...         H
# 126  JESSICURL Gelebration Spray – krem do stylizac...         H
#
# [303 rows x 3 columns]

# %% [markdown]
# # Save and check dataset

# %%
path_to_output = r'C:\Users\Pszczółka\Projects\Data_Science_Projects\PEH_Classifier\Data_collection'
df_npk_final.to_csv(path_to_output + r'\Hair_cosmetics_by_PEH_loczek.csv')

# %%
df_npk_final_test = pd.read_csv('Hair_cosmetics_by_PEH_loczek.csv')
df_npk_final_test
# Out:
#      Unnamed: 0                                               inci  \
# 0             0  Water (Aqua/Eau),Carbomer,Polysorbate-20,VP/VA...
# 1             1  Water (Aqua),Eau),Glycerin,Fragrance (Parfum),...
# 2             2  Water (Aqua/Eau),Polyquaternium-37,Cyclopentas...
# 3             3  Aqua (Water),Cetearyl Alcohol,Cetrimonium Chlo...
# 4             4  Aqua,Cetearyl Alcohol,Myristyl Alcohol,Cetrimo...
# ..          ...                                                ...
# 298         122  Aloe Barbadensis (Aloe Vera) Leaf Juice,Nelumb...
# 299         123  Aqua,Sodium Hyaluronate,Benzyl Alcohol,Dehydro...
# 300         124  Aqua,Sapindus Mukurossi Peel Floral Water,Humu...
# 301         125  Linum Usitatissimum (Linseed) Seed Extract,Gly...
# 302         126  Aqua (Water),Linum Usitatissimum (Linseed) See...
#
#                                                  title peh_class
# 0    CANTU MOISTURE RETENTION STYLING GEL- żel utrz...         E
# 1    CANTU SHEA BUTTER COCONUT OIL SHINE & HOLD MIS...         E
# 2    Tigi Catwalk Curls Rock Amplifier – krem styli...         E
# 3    INSIGHT ENERGIZING MASK – emolientowa maska do...         E
# 4    DR. SANTE COCONUT HAIR Z OLEJEM KOKOSOWYM – ma...         E
# ..                                                 ...       ...
# 298  Holika Holika – wielofunkcyjny, nawilżający że...         H
# 299   Calaya – nawilżający żel hialuronowy, 2% (50 ml)         H
# 300  FITOKOSMETIK DROŻDŻE PIWNE AKTYWATOR WZROSTU –...         H
# 301  JESSICURL Rockin’ Ringlets Styling Potion No F...         H
# 302  JESSICURL Gelebration Spray – krem do stylizac...         H
#
# [303 rows x 4 columns]
